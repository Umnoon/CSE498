# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\asus\anaconda3\lib\site-packages (4.11.3)
# Requirement already satisfied: requests in c:\users\asus\appdata\roaming\python\python38\site-packages (from transformers) (2.26.0)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\appdata\roaming\python\python38\site-packages (from transformers) (1.21.4)
# Requirement already satisfied: huggingface-hub>=0.0.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.0.19)
# Requirement already satisfied: sacremoses in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (5.3.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\asus\anaconda3\lib\site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: typing-extensions in c:\users\asus\appdata\roaming\python\python38\site-packages (from huggingface-hub>=0.0.17->transformers) (4.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests->transformers) (2.0.8)
# Requirement already satisfied: click in c:\users\asus\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.3)
# Requirement already satisfied: joblib in c:\users\asus\anaconda3\lib\site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from sacremoses->transformers) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import torch
from transformers import BartForConditionalGeneration, BartTokenizer

# %%
input_sentence = "They were there to enjoy us and they were there to pray for us."

#A large BART seq2seq (text2text generation) model fine-tuned on 3 paraphrase datasets: Quora, PAWS and MSR paraphrase corpus
#https://huggingface.co/eugenesiow/bart-paraphrase

model = BartForConditionalGeneration.from_pretrained('eugenesiow/bart-paraphrase') 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
tokenizer = BartTokenizer.from_pretrained('eugenesiow/bart-paraphrase')
batch = tokenizer(input_sentence, return_tensors='pt')
generated_ids = model.generate(batch['input_ids'])
generated_sentence = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

print(generated_sentence)
# Out:
# Downloading:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/332 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# ['They were there to enjoy us and to pray for us.']

# %%
torch.cuda.is_available()
# Out:
# False

# %%
import torch
import matplotlib.pyplot as plt
from utils import get_cub_200_2011
from torchvision.utils import make_grid
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22580/1889517348.py in <module>
#       1 import torch
#       2 import matplotlib.pyplot as plt
# ----> 3 from utils import get_cub_200_2011
#       4 from torchvision.utils import make_grid
#
# ImportError: cannot import name 'get_cub_200_2011' from 'utils' (C:\Users\Asus\anaconda3\lib\site-packages\utils\__init__.py)

# %%
import torch
from transformers import BartForConditionalGeneration, BartTokenizer

with open('Ready2Paraphrase.txt', 'r') as f:
    result = f.readlines()
    
for each in result:
    input_sentence = each.strip()


#input_sentence = "They were there to enjoy us and they were there to pray for us."


    model = BartForConditionalGeneration.from_pretrained('eugenesiow/bart-paraphrase')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    tokenizer = BartTokenizer.from_pretrained('eugenesiow/bart-paraphrase')
    batch = tokenizer(input_sentence, return_tensors='pt')
    generated_ids = model.generate(batch['input_ids'])
    generated_sentence = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    print(generated_sentence)
    
    with open('paraphrase_all_captions.txt', 'a') as f:
        f.write(generated_sentence[0])
        f.write('\n')
# Out:
# ['An elegant looking brown and black bird with pale brown throat, breast and belly, black f']
# ['This bird is black with white and has a long, pointy beak.']
# ['A white and grey bird has grey feet and average proportions.']
# ['This bird is brown with white and has a very short beak.']
# ['A bird with a small pointed bill, whit eyering and superciliary, white wing']
# ['This is a medium sized birth with an orange crown, white bellow and grey back.']
# ['A small bird with blue gray crown, white belly and white and black wingbars.']
# ['This bird has a pointed yellow bill with a white breast.']
# ['This bird has wings brown and has a black crown.']
# ['A small yellow bird with black wings and a short black pointed beak.']
# ['A small plump grey bird with a crown the sticks up and black and white wings.']
# ['This small green bird has a yellow head and black eyes.']
# ['An off white bird with a light grey beak and dark red face.']
# ['This bird has a brown colored breast and belly, with a black cheek patch.']
# ['Mostly white bird with gray feathers and some black tail feathers and a blunt looking orange be']
# ['This particular bird has a belly that is white and black and has some tan patches.']
# ['A brown bird with a white and brown speckled breast, white throat and black eyebrows']
# ['This bird has a yellow belly with a grey neck and brown crown.']
# ['This bird has wings that are black and yellow and has a red face.']
# ['This bird has a yellow ish  white belly and breast, wings with two brown wing']
# ['This bird has wings that are black and has an orange bill.']
# ['bird has a big black head, the beak is long and the throat is black,']
# ['A small round bird with brown feathers and white spots along the wing tips and belly.']
# ['Grey and white bird with black head and red eyes with long orange bill.']
# ['This is a very small fluffy bird with a white head and body and grey wings. The']
# ['This particular bird has a belly that is white with brown patches.']
# ['A bright bird with an all red body with black undertones and an orange bill.']
# ['This large grey bird has a long large yellow beak and webbed feet.']
# ['This is a bird with a yellow belly and a brown head with a black eyebrow.']
# ['This bird has wings that are yellow and had a white belly.']
# ['A small bird with an orange body and a brown head and feather is sitting on a wire']
# ['A brown and white water fowl with red eyes, a long pointed beak and spiked']
# ['This bird has brown wings and has a white belly.']
# ['This bird is black and white in color, with a black beak.']
# ['This bird has a brown crown, brown primaries and a brown throat.']
# ['This large bird has a black stripe on its crown and a large orange and black bill.']
# ['This bird has a long black bill, with a grey breast and belly.']
# ['This bird is grey with black and has a very short beak.']
# ['This is a bird with a white belly, black back and black head.']
# ['A mostly black bird with a black  white mix of colors on its face and tall black']
# ['This is a bird with a grey breast, brown belly and wings and black streaks on its']
# ['A small bird with a yellow chest and black around its eyes.']
# ['This little bird is black with a white belly and has a very big eyes and a yellow']
# ['Small blue bird with large black eye, tips of wings are blue, small bill.']
# ['This bird has brown wings and white wings.']
# ['A white bird with black eyes, a black beak and black spots on its rectrices']
# ['A small bird with small pointed bill, brown crown and fluffy grey breast.']
# ['This is a bird with a black breast, grey wing and white spotted face.']
# ['This bird has black eyes, white throat, breast and abdomen, and white outer rectrices']
# ['The bird has black throat, breast, belly and brown tarsus and feet.']
# ['This bird has a red beak and grey plumage with a creamy grey belly.']
# ['This bird has an ivory beak, a red breast, a white abdomen, black eyes']
# ['A small nearly black bird with a light blue eye, a red bill, a dull white']
# ['This light colored bird has a white belly, with brown speckles all over with a']
# ['This bird has a brown crown, brown throat and white breast.']
# ['This bird is green with blck and has a very short beak.']
# ['This small bird with an orange ring around its nape has a short pointed bill.']
# ['The crown is white, the bill is long and brown, and the belly is white.']
# ['A medium sized bird with light grey belly with patches of blue, a white throat and a']
# ['A small dark gray perching bird with a white throat and belly, its wings are large']
# ['This bird has a small straight bill, a red crown, throat, breast and belly,']
# ['A yellow bird with grey and brown wings.']
# ['This bird has wings that are grey and has a yellow bill.']
# ['This small black-eyed bird has blue feathers on the crown extending down to the breast and']
# ['This bird has a long thin yellow beak with black on the tip, a black crown']
# ['A large brown bird with a long neck and a large head.']
# ['A bird that is jet black all over with a pointed beak.']
# ['A fluffy grey bellied bird with dark grey cheek patches and a grey long tail.']
# ['This particular bird has a belly white with brown spots.']
# ['This small yellow bodied bird has a grey head and white eye ring.']
# ['This bird is mostly brown with a white head and wingbar.']
# ['This completely black bird has a very long neck and a wide tail.']
# ['This bird has a white belly, white breast and a short pointed black bill.']
# ['This bird is white with black and has a long, pointy beak.']
# ['gray bird with black feet and a long black bill.']
# ['This bird has wings white and has a yellow bill.']
# ['A small bird with a cream colored breast, small pointed light orange bill and brown coverts']
# ['This small bird has a yellow belly of soft, downy feathers, a short, downward']
# ['A large bird with a black crown and red eyes, has a long curved bill.']
# ['This small gray bird has a white abdomen and a black pointed beak.']
# ['This bird has wings that are brown and has an orange crown.']
# ['The beak is long and very slender compared to the birds head and body.']
# ['This bird has wings that are black and has a white chest.']
# ['This small, colorful bird has red feathers on its head and yellow underbelly.']
# ['This small bird has a blue round head and a short pointed beak.']
# ['This bird has a very short bill and colors all over its body that look very similar to']
# ['The bird has a brown back and a small black eyering.']
# ['This smaller bird has a white breast and a long curved beak.']
# ['This brown and tan multicolored patterned bird has white markings under its primary feathers.']
# ['A medium size bird with a long, white neck, black head and orange eye.']
# ["This bird's body is white, with grey feathered wings, white eyes and a yellow"]
# ['A medium sized bird with grey wings and a thick, stout bill.']
# ['A small bird with a grey crown and yellow throat, chest and belly, and short grey']
# ['This bird has a brown and cream striped crown and breast.']
# ['This is a black bird with a white throat and a red head.']
# ['Small to medium grey black and white bird with medium tarsus and medium black beak']
# ['A small black and red bird with a round belly, small pointy bill, with a']
# ['A fat black bird with orange wings and a white stomach.']
# ['A small bird with a yellow eye brow and brown and white feathers covering the rest of its']
# ['This colorful bird has a green and black head, brown and tan coverts, blue black']
# ['The bird has a small black bill and striped wingbar.']
# ['The bird has a striped crown and a white breast.']
# ['A bird with yellow belly and breast, brown wings and rectrices and the bill is short']
# ['This particular bird has a tan belly and brown throat and a black crown.']
# ['A small bird with dark brown and black wings, white eyebrows and a short bill.']
# ['A large bird with white and black coloration and a long orange beak.']
# ['A bird with fluffy feathers, a white belly, a brown back and gray tipped tail feathers']
# ['This bird is black and has a long, pointy beak.']
# ['A medium bird with light grey feathers and black tips on the wings.']
# ['This bird has blue wings and yellow eyes.']
# ['A tan bird with a cream colored belly and a short brown beak.']
# ['This bird is black, white and yellow in color, with a black beak.']
# ['This short tailed bird is brown with light brown on its breast and throat.']
# ['A dull tan bird with dark brown wings and crown.']
# ['This small bird has a very long dark blue bill with grey and white markings on its head']
# ['This bird is black and white in color, with a black beak.']
# ['This bird has brown wings and has a black face.']
# ['This particular bird has a belly that is brown and white spotted.']
# ['This bird has a brown crown, a white breast and a large wingspan.']
# ['This bird is brown and white with green on its head and has a long, pointy']
# ['This large black bird has white spots on its tail and a white throat, breast and abdomen']
# ['This bird has a black crown as well as a white bill.']
# ['This bird is white with black and has a long, pointy beak.']
# ['This is a small bird with a brown nape, yellow rump and throat and red']
# ['This bird is colored with a mix of yellow and brown and a large set of black eyes']
# ['This bird has a white breast and long black and yellow beak, with black eyer']
# ['This small bird has a color of reddish brown that tapers to the tail with a']
# ['A white bird with black wings and legs and an orange beak.']
# ['A small grey and brown bird with white and black spots throughout its body.']
# ['This bird has yellow on its belly, breast and primary and secondary wings.']
# ['This brown patterned bird has a small, flat head and a very small beak.']
# ['This medium-sized bird has a tall looking crown and a light colored belly.']
# ['This is a bird with a white belly and brown back and head.']
# ['This bird is yellow with grey and has a very short beak.']
# ['This bird has black and yellow feathers with a small head and long beak.']
# ['A small bird with a yellow breast and long pointed beak.']
# ['A small bird with a gray belly and nape, brown and black wings and back and']
# ['This is a yellow and black bird with a pink bill and a black throat.']
# ['This is a bird with black and white wings and a red nape.']
# ['This bird has a brown crown as well as a small black bill.']
# ['This bird is red and brown in color, with a brown beak.']
# ['The bird has a black bill, curved throat and striped throat.']
# ['This bird has brown and white feathers and long legs.']
# ['This bird has a yellow body, black and white striped wings, a long tail, pink']
# ['This black and white bird and a mohawk and a long, pointed black beak']
# ['This white, blue and grey bird has such a short neck that its head seems to flow']
# ['A small brown and white bird with red around the eyes and very long compared to its size']
# ['This bird is red with black and has a very short beak.']
# ['This bird has a black and yellow crown with back bill and yellow belly.']
# ['This bird is colored in mottled shades of gray with a vivid yellow throat.']
# ['This bird has a white belly with its chest being an orange `` red color and its head']
# ['This bird has wings that are black and a white belly.']
# ['This bird has a long, curved neck, a short bill and greyish brown feathers.']
# ['This particular bird has an orange brown belly and black breast and brown secondaries.']
# ['This bird has a white body, brown wings and a brown head, with its black be']
# ['This bird has black wings and has an orange belly.']
# ['The bird has a long bill that is black as well as white breast.']
# ['This bird has a long, slender beak with a yellow green body and some blue across']
# ['This bird is white with black spots and has white feet.']
# ['This bird is brown in color, with a skinny sharp beak.']
# ['A small bird with a short yellow orange bill with a black tip, a black crown and']
# ['This bird has brown wings and has a white belly.']
# ['This bird has black wings and orange eyes.']
# ['This bird has brown wings and has a white belly.']
# ['A multicolored bird with a white belly and chest, black and white wings and a']
# ['This bird has a short bill, a brown crown and light yellow tarsuses and feet']
# ['This small bird has brown plumage and a thin black bill.']
# ['This bird has a red belly and breast with a black wing and tail.']
# ['This bird is brown and white in color with a small black beak and black eye rings']
# ['This particular bird has a belly that is all black and red cheek patches.']
# ['This bird is yellow, black and brown in color, with a sharp beak.']
# ['This bird has grey primaries, white crown and white breast.']
# ['A small bird with a white belly speckled chest and a tiny copper bill.']
# ['This bird has wings that are black and has an orange bill.']
# ['This bird is grey and has yellow wingbar and sides with a white breast and grey feet']
# ['This bird is brown with grey and has a very short beak.']
# ['A large white bird with a long orange bil and black crown.']
# ['This bird is blue with white and has a very short beak.']
# ['A small bird with a white belly.']
# ['These birds are large and white with a little black on its head with a long beak']
# ['This bird has a small curved beak, black and brown striped breast and wings, a']
# ['This bird has wings blue and has an orange big bill.']
# ['This bird has a white breast neon blue tailfeathers and a long wide beak']
# ["This bird's belly is white with an orange patch, and it has a red face and"]
# ['This little bird has a white belly and breast with a speckled breast and wing.']
# ['The bird is small but has a large black bill, head is black and neck white,']
# ['This bird is light brown with orange eyes and a small pointy beak.']
# ['The small brown birth has black stripes on the head and the beak is straight.']
# ['A small bird with a green body and a yellow head with black stripes.']
# ['The bird has a white belly and striped brown back and wingbar. This bird has white']
# ['Blue bird with white brown breast and white torso.']
# ['This bird has a yellow orange head, breast and belly, and black ad coverts.']
# ['A large bird with green feathers and brown feathers.']
# ['This bird is black with white on its stomach and has a long, pointy beak']
# ['A small bird with a white belly and orange beak.']
# ['The bird has a white body and bright orange webbed feet with a sharp pointed bill.']
# ['This bird has a brown and white breast and a small black bill.']
# ['A small bird with an orange body and a brown head and feather is sitting on a wire']
# ['A yellow and brown bird with a yellow throat and black eyerings.']
# ['The bird has a black bill and black eyering that is round.']
# ['A large white bird with a very long orange bill, and orange webbed feet.']
# ['This is a tiny bird with a white belly, breast and throat and with a grey crown']
# ['A bird that stands tall but is small and has some patches of white on a brown to']
# ['A bird with grey tarsus and feet, the bill is short and pointed, with']
# ['A colorful bird with a blue nape and breast, with a green back.']
# ['This bird is orange with black and has a very short beak.']
# ['A small grey bird, with a white belly and a pointed bill.']
# ['The bird has a brown back and a small black eyering.']
# ['A small stout white breasted bird with a large orange and black beak.']
# ['This bird is white with black and has a very short beak.']
# ['The bird has a thick body with a bright orange bill.']
# ['This bird has a small red head with black wings and a white breast and belly.']
# ['This bird is small with brownish and white feathers and a long tail.']
# ['This birds black crown continues to run down the nape of its long neck, while its']
# ['A brown sparrow with black and white striped crown, brown tail, brown wings with black']
# ['Black throat and crown with white head, brown belly and back and red primaries.']
# ['This bird has wings that are black and a white belly.']
# ['A small gray bird with white underbelly and gray feathers.']
# ['A black and red bird with a small head, short legs, a long tail, black']
# ['The beautiful bird while flying is showing off its mostly brown body with a touch of white on']
# ['The bird has grey body feathers, white breast feathers and orange beak.']
# ['Small bird with black and white breast and black crown.']
# ['A bird with a stark red eye, swept back black crown, long neck and red wings']
# ['This bird has a long tail, short legs, a long pointy beak, a']
# ['This bird has a brown head, breast and back and black eyerings, wings and']
# ['This is a bird with a white belly, orange breast and black head and back.']
# ['This bird has a white belly and breast, a gray crown and white wingbars.']
# ['A small bird with a light tan belly, brown coverts and a near white eyebrow.']
# ['This bird has long brown wings with black secondary feathers and white wingbars.']
# ['This bird has a dull brown head and white superciliary, the bill and legs are']
# ['This bird has black wings and has a big bill.']
# ['This is a medium sized grey and black bird, it has a grey breast and abdomen and']
# ['This bird has wings blue with red eyes.']
# ['This bird has an orange and black bill and a white breast.']
# ['This bird has wings yellow and has a grey head.']
# ['A small bird with long legs and dark in color.']
# ['This bird has wings yellow and has a grey body.']
# ['An all black bird  a white patch underneath the primary wing tips, very long wings and']
# ['This bird is brown with white and has a very short beak.']
# ['This bird is brown with black and has a very short beak.']
# ['This bird has wings that are black and a white belly.']
# ['This large bird is mostly black with a long blunt bill.']
# ['This bird is yellow and dark grey in color, with a skinny flat beak and a']
# ['A medium sized bird with a gray belly, black and white back, with a red n']
# ['This bird has black wings, tail and back, a white head, belly and upper tail']
# ['This bird has a black crown and nape with grey coverts and white body.']
# ['A small bird with speckled brown, white and grey feathers all over its head,']
# ['This grey bird has black and white primary and secondary as well as a grey bill.']
# ['This particular bird has a white belly and yellow breasts and red eye rings.']
# ['This particular bird has a grey crown and a orange body.']
# ['This bird is white and brown in color, with a sharp beak.']
# ['This soft bellied bird has a hint of yellow in the wingtips and a rusty red']
# ['This bird has a white and black striped face, brown and tan colored coverts and a']
# ['This is a small monochrome bird, even the beak is black, with the']
# ['The bird has a straight black bill that is long and has a spotted back.']
# ['This grey and brown bird has a small head, with a light grey breast, darker secondary']
# ['A small bird with a black and white head, a long tail, long narrow legs and']
# ['This bird has wings that are grey and has a red crown.']
# ['A plump bird with white and grey colored feathers with a curved beak.']
# ['A bright blue bird with black wings and tail feathers and a black bill with a sharp point']
# ['The bird has red eyering, a curved sharp beak, brown wings and white breast']
# ['A small bird with a white breast and a black crown.']
# ['This bird has a bright yellow neck and breast region, including a yellow eyering.']
# ['This large white bird has a black crown and a long pointed orange bill.']
# ['This bird is black with white and has a very short beak.']
# ['This colorful bird has a yellow chest, belly and breast, a black and blue head n']
# ['This bird is gray, black and blue in color, with a black beak.']
# ['A small brown bird with a light yellow eyebrow.']
# ['tiny bird with a very long brown tail, very short and pointy beak cream colored']
# ['A small  with speckled black and white back and wings, black crown and bright']
# ['A bird with a very small, straight bill, a black superciliary, and a']
# ['This bird has wings that are black and a white belly.']
# ['There is a black bird with a black beak and red eyes.']
# ['This bird is black, white and red in color with a stubby beak and black']
# ['This bird is black, with a bill and long retrices.']
# ['A bird with long slender bill, red head and white eyering and very small feet.']
# ['This small bird has a short beak and distinct feathers.']
# ['This bird has a grey body with a brown crown and a thin sharp bill.']
# ['This small bird is brown in color and has a curved down beak.']
# ['A grey and yellow bird with a long tarsus and gold eyes.']
# ['A bird with a black bill, brown eyering and white breast.']
# ['This is a bird with a yellow belly and breast and a black eye.']
# ["This bird's wings have white coverlets and black secondaries, the bill is thick and"]
# ['This bird has a long grey bill with a blue cheek patch and an orange eyebrow.']
# ['The bird has a yellow and brown belly as well as a black eyering.']
# ['This bird has a white belly with a bright red breast and a black back and wings.']
# ['Small bird that is mostly brown, with black and white mostly scattered on his underside.']
# ['This bird has a grey crown, a small bill and a long neck.']
# ['This bird has wings that are black and has a red and yellow patch.']
# ['A small green bird with a blue crown and long blue tail feathers.']
# ['This bird is grey white and black in color with a sharp black beak and black eye']
# ['A bird with a black back and crown, white belly and red throat.']
# ['mottled brown and white head, white breast, long tarsus, grey wing']
# ['This bird is grey with black on its tail and has a very short beak.']
# ['This bird has black wings and has a long neck.']
# ['sharp billed small bird with uniform brown body and fanned retrices.']
# ['This bird has beautiful wings that are layered in the perfect pattern.']
# ['This small brown grey bird has a red tail, red secondaries, longer red feathers on']
# ['Small roundish bird, with an off white abdomen, back and belly, brown wings with']
# ['A small bird with a grey and white belly and vent, black and grey speckled']
# ['The small bird has black tarsus, a red belly and breast and a blue head']
# ['A small black bird, with some  on its secondaries and a sharp bill.']
# ['There is a small bird with a white belly, black and white back and a red spot']
# ['This bird has a brown crown as well as brown and white wings.']
# ['This bird is grey with black and has a very short beak.']
# ['This green bird has a white breast and yellow beak and the head and beak are']
# ['This particular bird has a tan and brown belly and breasts and blue cheek patches.']
# ['This small bird has a white breast and mixed green wings, black and white.']
# ['A small brown bird with a white breast with dark speckles.']
# ['This small bird has a black bill and breast and a brilliant white crown.']
# ['This small yellow bird has a red patch on top of its head and a small, thin']
# ['A small bird with a yellow breast and a short pointed beak.']
# ['This bird is white with brown and has a very short beak.']
# ['This bird has a grey belly and breast with darker grey secondaries.']
# ['This small bird is various colors of black, white, yellow and orange, with a mostly']
# ['A small bird with white and brown strips all over its body and a little yellow above its']
# ['This black bird has a very bright orange malar stripe and a small hooked beak.']
# ['This bird has wings that are black and has a white bill.']
# ['This bird has brown wings and has a short bill.']
# ['This bird has a white belly with blue wings and a blue head.']
# ['This bird is black and has a long, pointy beak.']
# ['A medium sized bird with a navy and black face and head, black vent and rump']
# ['bird with black crown, nape and throat, and white breast and belly, and orange']
# ['This bird has a black mottled back, tail and rump.']
# ['This small bird has a lime green shell and a small bill.']
# ['This white bird has a thick black bill and large tarsus and feet.']
# ['This bird is black with white on its stomach and a short beak.']
# ['bird with yellow sides and yellow breast with green back and short tiny beak.']
# ['This bird is brown with black on its back and has a very short beak.']
# ['This bird is brown with white and has a long, pointy beak.']
# ['This bird has wings that are black and a white belly.']
# ['This particular bird has a belly that is gray and brown and white.']
# ['This particular bird has a yellow belly and breast with black sides.']
# ['A bird has a white crown, a black eye and a throat and belly that are white']
# ['This bird has a brown overall body color with some streaks of white all over.']
# ['The bird has a grey body, with a white belly and a pink, triangular beak']
# ['A small bird with a large belly, long tail, small head, short legs, striped']
# ['This bird has black wings and white belly and back with a bit of red on its crown']
# ['A large bird with long curving wings, white body with a black cap covering the top']
# ['This bird has wings that are blue and has a white belly.']
# ['This bird has a red crown with yellow black and brown feathers on its wings.']
# ['This bird has wings that are black and white and has a red crown.']
# ['This particular bird has a belly that is brown and red and tan spots.']
# ['This bird has a bright red head and throat with a long sharp bill.']
# ['This is a yellow and grey bird with a large pointy white beak.']
# ['A small bird with white underside and brown wings.']
# ['This is a red headed bird with black and white wings and a long pointed beak.']
# ['This short and round bird has a tiny beak and brown and white feathers.']
# ['The bird has a small black bill, yellow belly and breast and grey wingbar.']
# ['This bird is red with black on its wings and has a long, pointy beak']
# ['This black and white bird with a striped pattern on its feathers has a distinctive orange patch of']
# ['The bird has a lightly colored brown breast, throat and belly. It has a darker brown']
# ['This bird has wings green and grey and has a red belly and blue head.']
# ['This bird is brown, white and black speckled all over, except for the ret']
# ['This bird is white with grey on its head and has a long, pointy beak']
# ['This bird has a grey head, yellow body, long tail, striped wing and a black']
# ['This is a bird with a yellow belly, black breast and brown back.']
# ['A bird with a whiter breast and black wings and a short pointed beak.']
# ['A dark grey bird with white tips on the feathers and tail.']
# ['This water bird has a long and narrow yellow beak, a white throat, a black']
# ['A green bird with a blue head, down to its nape, and black from its']
# ['A small bird with a yellow nape with black and white covering the rest of its body']
# ['A bird with a long small beak, yellow neck and belly with brown and white pattern']
# ['This small bird is mostly speckled with brown on its crown and nape.']
# ['A white bird with a black crown and a red bill.']
# ['This large bird has a brown head a large black beak and grey and white feathers throughout']
# ['Small bird that is mostly black with a black bill, tarsus and feet, it']
# ['A small bird with dark red coloring and pointed beak.']
# ['A small bird that has tones of grey and black and also a short bill.']
# ['This bird has wings white and has an orange bill.']
# ['This is a long billed and multi-color bird that is mostly black, with a brown']
# ['A small brown bird, with a black throat and a small bill.']
# ['A bright orange bird with a black head and black wings.']
# ['A small bird with a long, pointed, black beak and brown spots along the breast']
# ['A small bird with a long, sharp bill and red cheek patch speckled with black']
# ['This is a white bird with a grey wing and a yellow beak.']
# ['Big white bird with orange feet and beak long wings.']
# ['This bird has a white and black striped face, brown and tan colored coverts and a']
# ['This small bird has a white belly and breast with a black neck, crown and nape']
# ['This bird has a red body with paler spots closer to its tail, along with light']
# ['A small bird with a black head, face, coverts, secondaries and rump']
# ['This is a small bird which is mainly orange, with the exception of parts of the wings']
# ['This bird has a small sharp bill, a black crown, an orange belly and breast,']
# ['Brown and black bird with dark eyering and short bill.']
# ['The bill of the bird is short, pointed, and black, and the body is a']
# ['This bird is black and white in color and has a long white bill along with a white']
# ['This bird has brown wings and has a yellow chest.']
# ['A small brown bird, with a darker crown and a short bill.']
# ['This is a not so small bird with a body of bright yellow and grey feet.']
# ['This particular bird has a belly white with black spots.']
# ['A small bird with a yellow bellow and breast and gray wings and head.']
# ['This is a medium sized bird with a light breast and abdomen that is speckled,']
# ['This bird has a white neck and throat, a black crown, grey wings and back and']
# ['This bird has wings that are black and a white belly.']
# ['This bird has a speckled wing and back, with a red crown and a long']
# ['Red, pink bird that looks like a large beak.']
# ['This bird has a speckled belly and breast with a long pointy bill.']
# ['This is a small bird with brown wings and white belly and a long orange beak.']
# ['This bird has a white face, brown wings and a very long white hooked beak.']
# ['A small bird with a small beak, brown body and white belly.']
# ['This particular bird has a belly white with patches of brown.']
# ['This tiny little guy has an orange beak and a black head with a white neck.']
# ['This bird has a white belly and breast with a brown crown and superciliary.']
# ['The bird is small, black head, with a tuft of yellow around the eyes.']
# ['A smaller sized bird with a light grey under belly, dark grey and white striped wing feathers']
# ['A bird with a large belly fat and spotted wings.']
# ['A bird with completely tan belly, dark brown eyebrow and tan coverts.']
# ['This bird has wings that are grey and has a white belly.']
# ['A small bird with a dark orange head with dark brown wings that have white wings.']
# ['This medium sized bird has a longish neck, bright red eyes with thin red skin going']
# ['The bird has a large black bill curved and a red eyering.']
# ['This sleek bird is light grey through most of its body, with a darker crown and secondary']
# ['This bird has brown wings and has a black bill.']
# ['This particular bird has a belly that is black and dark gray.']
# ['A bird with a white bill and breast and black crown and the bill is short and pointed']
# ['This bird has a green crown, green primaries and yellow belly.']
# ['This bird has feathers that are black and white and has a red crown.']
# ['A small bird with a white head, chest and belly, black nape and blue back']
# ['This bird has a brown crown, a black bill and a round breast.']
# ['This large white bird has a long neck and a long orange beak.']
# ['This bird has a gray belly and a colorful yellow and green head.']
# ['This primarily white bird stands on some sand with its orange feet while its black tail is almost']
# ['The color of the bird is blue with greyish beak and black beady eyes.']
# ['This bird has a brown crown, a pointed bill and a spotted breast.']
# ['A bird with a long small beak, yellow neck and belly with brown and white pattern']
# ['This bird has a white belly and breast with a long hooked bill.']
# ['A small dark brown bird with a white belly and pointy small black bill.']
# ['This bird has a round body and a tiny head with an rust colored tuft on its']
# ['This bird has wings that are black and a white belly.']
# ['This small bird has a yellow supercilliary and a white breast.']
# ['A very small black bird with yellow and red on its chest.']
# ['The bird has a yellow bill that is curved as well as black.']
# ['This is an orange bird with a black wing and a black head.']
# ['This bird is black with orange and has a long, pointy beak.']
# ['Black and white bird with all white torso, black and white head, and also black and']
# ['This bird has wings brown and black and has a grey belly.']
# ['This bird has a white body and head, with grey and black wings and an orange medium']
# ['This bird has white wingbars with wings that vary from yellowish to grey on a gradient']
# ['A small yellow bill and a dark brown malar stripe.']
# ['This bird is red with black wings and has a very short beak.']
# ['Small blue white and black bird with long black tarsus and medium black beak.']
# ['This is a black and brown bird with black wings and a dark pointy beak.']
# ['This bird has a pointed black bill and a brown back.']
# ['This is a grey bird with a black rump and beak.']
# ['This bird is black, has long wings and has a long, pointy beak.']
# ['A very small, light brown bird with a slightly curved bill and small dotted wingbars.']
# ['This is a yellow bird with grey wings and a grey head.']
# ['This bird is grey with brown and has a very short beak.']
# ['This pudgy bird has a stout short bill, dark supercillary, and soft']
# ['This bird has a long yellow bill that curves slightly downward at the end and a white body']
# ['This is a small bird with a red head, throat and breast with a black bill and']
# ['This bird is black and brown in color with a black beak and black eye rings.']
# ['A medium sized bird with a green body and a black neck.']
# ['The bird is grey and has an orange beak with white belly.']
# ['A black and white bird that is black on its dorsal side and white on its ventral']
# ['This bird has wings that are black and has a long bill and neck.']
# ['This bird is black with white and has a very short beak.']
# ['This water bird has a long grey neck, black bill and black upper tail coverts.']
# ['This bird has a cream breast, a light brown side and flank, a chestnut crown']
# ['A small colorful bird with a yellow breast and belly, black throat and brown and white secondary']
# ['This small bird has a yellow bill pointed downward, a dark brown crown, a tan eyebrow']
# ['This bird is brown and has a large beak.']
# ['The yellow bird has a black beak with brown wings and white wingbars.']
# ['A tiny bird with a white belly, pink tarsus and brown and black striped wings']
# ['This particular bird has a belly that is gray and white.']
# ['This interesting bird has an orange belly and breast with white spots on the underside of its black']
# ['This bird has a black bill with black crown and long wings with grey secondaries.']
# ['A bird with a large downward curved bill, white throat and head, brown breast and white']
# ['A small bird with black and reddish brown crown, cream and black nape with grey']
# ['This is a green bird with a blue tail and blue head, while the neck is black']
# ['This bird is white with brown and has a very short beak.']
# ['This bird has wings that are yellow and black and has a white body.']
# ['This is a bird with a white belly, brown breast and blue head and back.']
# ['This small bird has black wings and a black bill with a yellow crown and breast.']
# ['This bird has a black back, black and white wings that have red feathers underneath, a']
# ['A small yet round bird with a white and blue body.']
# ['medium to large black and white bird with long neck and long beak.']
# ['This bird has a fluffy white breast, short pointed black bill and black retricles.']
# ['This bird is nearly all gray with a blunt beak.']
# ['The bird has a small yellow bill, grey belly and breast and striped wingbars.']
# ['What is the length of the feathers in a bird?']
# ['The small bird is plump with a yellow body and a sharp pointed beak and black']
# ["This    bird `` has ''   a   green   body,"]
# ['This bird has a plump body with gray and brown feathers.']
# ['A light brown bird with small, dark brown spots and a light colored underbelly with']
# ['This bird has brown wings and has a white belly.']
# ['A small bird containing bright feathers covering its entire body and a black eye ring.']
# ['This bird has a white crown, a large orange bill and a large wingspan.']
# ['This is a yellow bird with a black crown and a grey wing.']
# ['The eyebrow and throat are yellow, while the cheeks, crown and breast are black, and']
# ['This bird has black wings and has a yellow body.']
# ['A larger bird with white underbelly and light grey wings.']
# ['This bird has a white body with some grey shading on its back,  shaped white tail']
# ['This bird has a speckled pattern all over with a tiny pointy bill.']
# ['A mainly olive colored perching bird with a yellow head that has dark brown stripes.']
# ['This bird is black with red eyes, a black beak and a black nape.']
# ['A unique bird with very dark coloring, a long bill, an orange superciliary and']
# ['yellow malar stripe on a grey winged bird with long tail and white breast.']
# ['Brown and off white speckled bird, some black on wings.']
# ['The birds has a blue overall color aside from its grey bill.']
# ['This bird has a pointed black bill with a yellow breast.']
# ['This bird is brown with white on its chest and has a very short beak.']
# ['The head of the bird is crowned with bright blue, a black chest pattern and a green']
# ['A small iridescent blue bird with brown interspersed throughout the secondaries and orange']
# ['This small bird has a yellow crown with two black stripes, a white throat, grey breast']
# ['This bird has brown wings and has a yellow belly.']
# ['This little bird has mostly solid yellow plumage with a small bill and black eyes with white']
# ['A small bird with a dark brown crown and white throat.']
# ['This is a large bird with a brown body and tail and white breast.']
# ['This bird is brown with a white belly with stripes and orange feet.']
# ['This is a white bird with grey wings and a black head.']
# ['A smaller, spotted bird with blue legs, a long beak and a pointed tail.']
# ['This bird has a short pointed black bill, grey crown with yellow superciliary and black']
# ['The bird has a striped crown, curved throat and red eyering.']
# ['A chocolate and beige coloured bird with a wide yellow beak and angular black eyes.']
# ['This is a brown and tan bird with a gray belly.']
# ["This bird is mostly black with a yellow belly and u-shaped white along it's wings"]
# ['The bird is black with long black tarsals and a short black beak.']
# ['Brown bird with black in wings black beak white nape.']
# ['The bird has a yellow bill that is curved as well as black.']
# ['This bird is green with black and has a long, pointy beak.']
# ['This particular bird has a black secondary and white throat and long grey bill.']
# ['A small bird with a narrow, small pointed beak and black eyes covered in dark blue']
# ['This bird has wings black and white and has a red head.']
# ['This bird has a short wide bill, a white throat and a white cheek patch.']
# ['The bird has a red crown, large black bill and large wingbar that are black and']
# ['This is a small green bird with a white breast and belly and orange sides, as well']
# ['This bird has a long thin bill and a dark reddish brown head.']
# ['This bird has wings white with black belly.']
# ['The bird has curved feet and a grey breast and throat.']
# ['This bird is brown and black with spots all over it, it has a small pointed be']
# ['This bird is black with white and has a long, pointy beak.']
# ['The bird is brown in color and has a neck that is curved in shape.']
# ['This small colorful bird has green wings and yellow throat.']
# ['A small bird with a short, flat beak and a vibrant blue body.']
# ['A bird with a white breast and a multicolored crown.']
# ['This bird has a white belly, a grey crown, with a black cheek patch and a']
# ['This white bird has a long and pointy, orange beak with a black crown that']
# ['This is a bird with a pink breast, brown wings and a pink face.']
# ['A small colorful bird consisting of bright yellow along its head, nape face, throat,']
# ['This bird has a narrow black bill with orange, black and white body.']
# ['The bird has two skinny thighs, a small bill and black eyering.']
# ['This particular bird has a belly white with black spots.']
# ['This bird has brown wings and has a long bill.']
# ['The bird has a white belly with a brown crown and a white throat and a red ey']
# ['The bird has a curved neck that is spotted and a large black bill.']
# ['This bird has a black crown, brown primaries and brown belly.']
# ['medium to large grey and white bird with long black beak.']
# ['This is a round white  with grey specs on its breast with a small beak and']
# ['This bird has a bright red head and a long beak. It has a black back']
# ['A brown bird with very small bill, a large breast area and wings.']
# ['This bird has wings that are black and has a long bill.']
# ['This small bird has hints of green on his wings and a very long black beak.']
# ['A small bird with short pointed bill, white breast and blue head and wingbar.']
# ['This bird is green with white and has a very short beak.']
# ['A small bird with a short pointy beak and black head.']
# ['This bird has brown wings and has a spotted belly.']
# ['This bid has a white crown and back, and black feathers covering the rest of its body']
# ['This bird has black wings and has a blue head.']
# ['This bird is brown with black on its head and has a long, pointy beak']
# ['A small brown bird, with a very short curved bill.']
# ['This bird is grey with black and has a long, pointy beak.']
# ['This bird has a small bill, a white throat and a brown belly and breast mott']
# ['A sleek black bird with a sharp beak and small eyes.']
# ['This bird has a light green and yellow crown along gray outer rectrices with gray secondaries']
# ['A small brown and tan bird, with a white speckled breast.']
# ['This small bird is bright red throughout its body with a thick bill.']
# ['This upright bird is brown throughout and it features beady black eyes and a slightly curved be']
# ['The head of the bird is grey and the body of the birds is black and white spe']
# ['This bird is white, black and orange in color, with a black beak.']
# ['This bird has a long wingspan, a short pointed bill and a brown crown.']
# ['A colorful bird with a yellow head, black neck and yellow body, with black wings.']
# ['This bird is brown with white on its belly and chest and has a long, pointy']
# ['The bird is small with a pointed bill and the belly is black.']
# ['A bird with yellow belly, breast and rectrices, the short pink bill and pointed and']
# ['This bird has brown wings and has an orange bill.']
# ['This bird is yellow in color, with a small sharp beak.']
# ['This is a yellow bird with green wings, a blue head and a black throat.']
# ['This bird is fairly beige with a red crown and yellow stripes on the wings.']
# ['The bird is calico and checkered in its wings consisting of black and white.']
# ['This tiny bird has a little beak with wings that are various shades of brown and a']
# ['The little bird has a bright yellow chest accompanied by a grey and brown backside with white']
# ['This bird is brown and white in color, with a light colored beak.']
# ['This is a bird with a white belly and a yellow eye.']
# ['This bird is brown with white and black and has a very short beak.']
# ['This is a very colorful bird with bright yellow on its back, breast and belly.']
# ['A small yellow bird with a white breast, crown and black tips on wings.']
# ['The small bird has a white color underneath, brown patterned on the back and yellow patches']
# ['This bird is yellow with black and has a very short beak.']
# ['This large bird has a white nape, black crown, black primaries and secondaries with']
# ['A light colored small bird with a pointy brown beak.']
# ['Small red  brown bird, with an  large bill, with outlines of turquoise']
# ['The bird is brown and white in color with a small black bill.']
# ['This medium sized bird soars in the sky, resembling a hawk, with small patches of']
# ['A small bird with a white belly, black crown and back, with a short curved bill']
# ['A blue bird with orange wingbar, a long tail and a stubby white beak']
# ['This bird has a very short orange colored bill and a black overall body color.']
# ['medium to large white grey black and brown bird with long brown beak.']
# ['This bird has a pointed brown bill with a brown breast.']
# ['A small, plump bird with gray breast and belly, a brown wingbar with white']
# ['This bird looks more like a  with short black yellow and orange bill and brown with white']
# ['A small black bird with pointed beak.']
# ['A white breasted bird with a white throat and a shiny blue crown.']
# ['Beautiful all yellow bird with long thin tarsus, black vents and black nape']
# ['This bird is red with a red throat, brown beak and a red crown.']
# ['This bird has brown wings and has a white belly.']
# ['A small bird with a tan eye ring, small pointed bill, cream colored breast and a']
# ['This bird is black and white in color with a long black beak and black eye rings']
# ['This bird has a dark blue body and head with rust colored wing bars, a black eye']
# ['This bird is brown and black in color, with a flat black beak.']
# ['This bird is mostly white with a black crown and long pointy bill.']
# ['The bird has a brown and white back and a long dark brown bill.']
# ['This bird has wings that are black and has a long bill.']
# ['The head and belly of the bird is white and the yellow beak is curved.']
# ['This particular bird has a yellow bely and gray breasts and white eye rings.']
# ['A small grey bird, with white eyebrows and a short bill.']
# ['A yellow, black and brown bird with a wide pointed yellow beak.']
# ['A small bird with a brown tail and wings and pointed beak.']
# ['This bird has a black crown, grey primaries and white throat.']
# ['This small bird has a black face, a black cheek patch surrounded by white and a redd']
# ['The bird is black and has orange wingbars, the bill is long and pointed.']
# ['This bird has a dark black body with white cheek patches, a large red crest and mal']
# ['A red eye ringed bird, with a flat bill, dark crown, white cheek patch']
# ['This bird has brown wings and white wings.']
# ['This particular bird has a belly that is gray and white.']
# ['This black and white bird has a thick bill that is orange and red.']
# ['A small bird with a cream colored throat belly and breast, grey side and brown wings with']
# ['This bird is black with white and has a very short beak.']
# ['A small bird with yellow and grey feathers, a small head and small pointy beak']
# ['A large white bird with huge wings and a large orange beak.']
# ['medium sized all black bird with a black bill that curves slightly downwarda small bird with red']
# ['This is a yellow bird with a black wing and a brown crown.']
# ['A bird with a black crown and white nape, the bill is long and pointed,']
# ['This bird has brown wings and has a white belly.']
# ['This is a brown bird with pink on its belly and a grey head.']
# ['A small bird with reddish orange tarsi, white breast and wide, but small']
# ['This bird has large black eyes with light eyering, a burgundy cheek patch and a']
# ['A small yellow bird with white and black wings, black superciliary and black beak']
# ['A big bird that is black throughout its body.']
# ['This bird has a red crown as well as a grey belly.']
# ['This bird has a white belly and breast with a blue crown and nape.']
# ['This bird is white and brown in color with a skinny curved beak and black eye rings']
# ['A black and white bird with a large wing span and yellow beak.']
# ['This bird has a brown crown, brown primaries and white belly.']
# ['A small grey bird with orange mohawk and yellow wings.']
# ['This bird has black primaries, a black crown and a red breast.']
# ['A sleek bird with a thick face and neck and a small bill with white cheek patches,']
# ['This little bird has a short beak, a white breast and tiny black round eyes.']
# ['This bird has a dark blue bill and crown with a white throat and belly.']
# ['This bird has a curved dark bill with black feet and a white breast with dark spots spl']
# ['This dull bird has a long thin body with a grey and white belly and black wings.']
# ['This large bird has a white belly and breast, black tarsus and feet and a']
# ['This large bird has a white head, throat, belly, chest and abdomen, the wings']
# ['This bird has very distinctive patter of colors with a red anterior face, white posterior face']
# ['This plump bird is mostly light grey, but with a dusky orange crown and yellow']
# ['This bird has a white crown, a yellow bill and large feet.']
# ['This bird has wings that are black and a white belly.']
# ['This bird is completely blue in color and has yellow eyes.']
# ['This is a small brown bird, with a white abdomen and a small sharp bill.']
# ...
# ['This bird has brown wings and has a short bill.']
# ['This bird has brown wings and has a white bill.']
# ['The bird has a tan striped belly and neck, with brown striped wings tail and head.']
# ['The bird had a small crown and a large breast.']
# ['The bird had greyish black feathers on its entire body with red, yellow and white on']
# ['A small yellow bird with black and white striped wings and short tail, short legs, a']
# ['The bird has a red eyering as well as a white breast.']
# ['A bird with a long wingspan and a grey and white coloration.']
# ['The bird is small and fat with no head and neck, a skinny long beak and']
# ['A small brown bird, with a long tarsus and a pointy bill.']
# ['A black bird with orange markings.']
# ['A bird with a large outer rectrices, a green breast with grey throat.']
# ['Brown bird with a long brown tail, a light eye patch, yellow eyes and a spe']
# ['This bird has brown wings and yellow eyes.']
# ['This blue, black, green and brown bird has a long pointy beak.']
# ['A bird with a short, pointed bill, black crown and nape, and an all']
# ['It has a small beak and light brown feathers on the bottom of its face, chest']
# ['A small bird with a curved head and colored black and tan.']
# ['This bird is completely jet black with a large bill, with black tarsus and large']
# ['This colorful bird has blue lower secondaries, neck and flank feathers, as well as black']
# ['This is a tiny brown and yellow bird with a short pointed beak and black eyes.']
# ['A long black bird, with a white rump and white flank.']
# ['gray in color and a very orange beak, very and looks like it has a m']
# ["This bird ``    has ''   a   dark belly,  "]
# ['The bird has a white crown, curved grey bill and grey sides.']
# ['This bird has a deep blue breast color and a snub bill.']
# ['A tiny yellow and white bird that has beady back eyes and a cute little beak']
# ['The small bird is bright blue in color with a short black bill.']
# ['The small bird has a grey body with a long tail that is grey and black.']
# ['This bird is brown with black and has a very short beak.']
# ['This bird has a long orange beak that has a black tip, the bird has light']
# ['This bird is brown and white in color, with a stubby beak. This particular']
# ['This small wood colored bird has a short pointy beak and a grey superciliary']
# ['A large black bird with a white patch behind its neck.']
# ['This bird has a very rusty black set of wings and crown and a red throat and belly']
# ['A bird with a short, pointed beak, orange eyering and cheek patch, gray']
# ['This is a tan bird with black and grey coverts and a long pointed bill.']
# ['A small bird with a yellow underbelly, yellowish gray wings and a grey head']
# ['A brown and white bird with a brown head and brown breast.']
# ['The bird has a light brown throat, with a brown colored abdomen and breast as well as']
# ['A small bird with white breast and belly, speckled cream and brown throat and white']
# ['This bird has a grey crown with a red spot in the centre, a red face and']
# ['This bird has brown wings and has a white belly.']
# ['This bird has a yellow crown, nape and breast, as well as a black cheek']
# ['A small bird with a cream colored throat and breast, with a grey head and black cheek']
# ['This is a bird with a red breast and a red head.']
# ['A medium sized bird with yellow stripes on a black head and some brown wings.']
# ['This bird is grey with black near its eyes and has a very short beak.']
# ['This bird has a black head with a black cheek patch, the bill is long and pointed']
# ['This bird has wings that are white and has a black bill.']
# ['A tiny bird with twig like yellow feet, off white, grey and black feathers and']
# ['This bird has brown wings and has a white belly.']
# ['This bird has a speckled belly and breast with a short pointy bill.']
# ['The bird is large with a pointed bill, has yellow eyering, and the belly is']
# ['This gray bird has a pointy beak with a vibrant yellow breast and white vent.']
# ['This particular bird has a belly that is white and gray.']
# ['This bird has a blue body and breast and a black tail.']
# ['The petite bird had a dark grey head in contrast to the bright yellow feathers and white']
# ['This small bird has black wingbar and long tailfeathers.']
# ['This bird has a blue crown as well as a white belly.']
# ['This bird has wings that are grey and has an orange belly.']
# ['This is a yellow bird with a grey wing and a pointy beak.']
# ['This small bird has a bright yellow belly and breast, at its nape the feathers are']
# ['This bird is yellow with black on its wings and has a very short beak.']
# ['This bird is red and black in color with a pointy beak and red eye rings']
# ['This particular bird has a belly that is yellow and white.']
# ['This bird is brown with black and has a very short beak.']
# ['This bird has brown wings and has a white belly.']
# ['This bird is brown in color with a very small beak and brown eye rings.']
# ['This bird has black wings and has a small black bill.']
# ['This tiny bird has a long black bill and a white breast and belly with grey wings.']
# ['The bird has a sharp beak and many different shades of brown.']
# ['Small bird and a small head and beak, the green color is predominant on the body']
# ['This bird has long wings with curves and a white stripe around the throat.']
# ['This bird has wings that are black and a white belly.']
# ['This bird has wings that are black and a white belly.']
# ['This bird has a white and brown breast and brown and black wing and tail feathers.']
# ['Black and white feathered birds with large wing span and long beak that curves downward.']
# ['The black bird features red on its face and black pointed head feathers.']
# ['This bird has a grey crown and bill and a yellow throat.']
# ['This little bird has a yellow belly and breast with a gray wing and white wingbar.']
# ['The bird has a short pointed bill with a white and brown body and has yellow on its']
# ['This bird has short wings and a very long skinny beak.']
# ['A small bird that is multicolored black, white and cream with a rust colored throat']
# ['A small yellow bird with a black beak, grey yellow coverts and grey secondaries']
# ['This bird is completely black with yellow eyes.']
# ['Small bird with yellow belly, flank and back with black covets with white wingbars.']
# ['A small bird with speckled brown, white and grey feathers all over its head,']
# ['This bird is black with long tail feathers and a large round beak.']
# ['The small bird is brown with a white belly and breast and has a sharp brown beak']
# ['This particular bird has a belly that is black with a yellow throat.']
# ['This bird has a brown head, a short bill and a dark brown belly.']
# ['This bird has wings that are black and a white body.']
# ['This bird has a blue head, nape and covert with a white belly and abdomen area']
# ['This beautiful bird has a brown breast, a shiny short bill and a black eyering.']
# ['This interesting bird has a blue back, wings, beak and head, a tuft']
# ['This bird is red with black and has a long, pointy beak.']
# ['Smaller grey bird with a yellow throat and breast, the wings also have a hint of']
# ['Small bird, light colored breast and belly  light tan, dark color top breast, dark']
# ['This bird has wings that are black and has a yellow belly.']
# ['This bird is white with grey and has a very short beak.']
# ['This is a brown and white bird with a brown crown.']
# ['This bird has a speckled belly and breast with a short pointy bill.']
# ['This particular bird has a belly that is black with a yellow and orange patch on the wing']
# ['This bird has a brown crown, a sharp bill and a brown back.']
# ['This bird has black wings and orange eyes.']
# ["A small bird has a very round belly, long tarsus '', and a spotted"]
# ['A small bird with a dark and pointed bill and dark feathers.']
# ['This bird has brown wings and has a white belly.']
# ['This small bird has light brown wings and a touch of yellow.']
# ['This small bird has a yellow throat and breast and wings which are grey with streaks of yellow']
# ['This black bird has a long neck, a short red beak, and each long foot']
# ['This is a white bird with gray wings, black head and a black beak that curves']
# ['A small grey bird with orange on its head and speckles around its body that are']
# ['This bird has wings that are black and has a yellow belly.']
# ['This white bird has a wide beak and brown wings.']
# ['A small bird with yellow and brown sides and back, brown wings and long, skinny legs']
# ['White bellied bird with greyish wings, tails and crown and bluish grey bill.']
# ['This bird has a long pointed bill, with a dark yellow breast.']
# ['This fat bird is light pink and light grey. The beak is short and the wings']
# ['This bird has wings that are grey and has a white belly.']
# ['This bird has a grey nape with a red cheek patch and black outer retrices.']
# ['The bird has a white breast, a grey side and a black eyebrow.']
# ['This bird has a white breast and belly with a small pointy beak.']
# ['This brown bird has a very short beak and a tan belly.']
# ['A small bird that is mostly shades of brown with a muted yellow belly and abdomen.']
# ['This bird has layered wings that have a striped pattern as well as a long, thin curved']
# ['This bird is white and brown in color, with a small beak.']
# ['This bird is brown and orange in color, with a skinny curved beak.']
# ['orange beaked yellow bird, with black and white wings.']
# ['This bird has a black bill with a light brown belly and orange tarsus and feet']
# ['A small white bird with a white breast and belly with a orange sharp beak.']
# ['This is a small gray and light brown bird with yellow coverts and a white abdomen.']
# ['The green wing has two white wingbar, the bill is long and pointed, and the']
# ['This bird has a broad, stubby black bill and black crown and throat.']
# ['This bird has an  black color over its whole body, also with a black pointed bill']
# ['Small chubby bird with bright orange feet and yellow and orange bill.']
# ['This bird has all black feathers and a black medium sized beak.']
# ['This bird has wings that are grey and has a long bill.']
# ['This spikey brown crowned bird has brown wings with white wingbars and a white neck.']
# ['A small white bird with an orange crown and darker wings.']
# ['The black head on the white bird makes the bird look smaller than it is.']
# ['This bird has a dark grey crown and bill and a white breast flecked in grey']
# ['The bird has a yellow breast with a fanned tail and a small head.']
# ['White bird with blue gray wings and black eye brow and crown with some brown on its underside']
# ['This little bird has a white belly and breast with yellow around its eye and brown and white']
# ['This is a white bird with a long wingspan and an orange bill.']
# ['This bird has a long, straight, gray bill, a dark brown crown and a white']
# ['This bird has black legs with a long black bill.']
# ['This bird has a skinny curved bill, a light grey crown and a spotted throat and breast']
# ['This is a large brown and grey bird with a long black beak.']
# ['This is a large white bird with a black breast and head.']
# ['The bird is black from beak to tail, but has very vibrant yellow eyes that stand']
# ['A bird that is white in the breast area, brown wingbar and reddish brown eyes']
# ['This bird is brown with black and has a long, pointy beak.']
# ['This brown bird with a white breast is standing on top of a']
# ['A petite bird with a bright red under belly, dark grey wing feathers and a short']
# ['A small brown and cream colored bird with a very small head and beak, light brown']
# ['This black bird is large in size with a big beak.']
# ['This bird has wings brown and black and has a white belly.']
# ['This bird has white wings and black feet.']
# ['This particular bird has a belly that is tan with white spots.']
# ['Small yellow bird with a small black beak and grey and yellow wings.']
# ['This bird is brown with white and has a long, pointy beak.']
# ['This bird has feathers that are black and has a red body.']
# ['The small bird has a sharp bill, coffee colored feathers and a light brown belly.']
# ['This bird has all white feathers, with black eyes and feet.']
# ['The bird has a small eyering that is black and small feet.']
# ['This black bird also has a black bill and black tarsus and feet.']
# ['A small bird with a fairly long, curved beak, a long tail and wings that']
# ['This bird is red with black and has a very short beak.']
# ['This is a white bird with long feathers and a white beak.']
# ['A big bird that has a black eyebrow, crown, nape, with a thick long']
# ['Small brown bird with green belly, wingbars, throat and eyerings.']
# ['This small bird has orange eyes, with a distinguishing white patch on its cheek patch against its']
# ['A bird with a green head to the wings and tail with a red breast and white belly']
# ['This is a bird with a tan belly, brown wings and a pointy beak.']
# ['This bird is a small head relative to his body, a white body and a small bill']
# ['This bird has a long and thin black beak, a brown crown, back and white']
# ['A small bird with a grey head and black nape, with grey and black covering the']
# ['This bird has a black crown, a black long bill and a white belly.']
# ['An all over purple bird with black eyebrows, yellow superciliary, throat and belly.']
# ['This bird has a white belly and breast with a grey wing and a long hooked bill.']
# ['This bird has wings that are black and a white belly.']
# ['This colorful bird has a yellow belly and breast, small bird with a black, white and']
# ['medium to large grey and white bird with long orange tarsus, webbed feet and']
# ['A tan bird with blue wings and a blue head.']
# ['This is mostly a black bird with a grey beak and red eyes.']
# ['This bird is white and grey and its eyes are very close together on its head.']
# ['This bird has a white belly, black wings and a brick red crown.']
# ['A brown and white bird with a small head compared to its body that has a small,']
# ['The bird is grey and brown with a black throat and black bill.']
# ['The bird has orange tarsus and feet, a black tail and a yellow body with']
# ['This small bird has streaks of grey, black and white.']
# ['This is a grey bird with white on the breast and a small bill.']
# ['This bird has a white chest with brown flecks going down to its belly, an orange']
# ['This bird is brown, black and red in color with a short black beak and black']
# ['This bird has a white body and head, brown wings and a long slightly curved orange be']
# ['This particular bird has a belly that is black and a blue throat.']
# ['Small white brown and yellow bird with medium pink tarsus and medium brown beak.']
# ['A small bird with red crown and nape and a tint of yellow on throat with red']
# ['This bird is blue with red and has a long, pointy beak.']
# ['A small cream colored bird with brown wings.']
# ['This small bird of the  has a short bill with brown and black colors covering most of']
# ['This large black bird has a stubby beak and a white band of feathers on the']
# ['This is a small orange bird with a black head.']
# ['A tiny bird with a black and white speckled body and striped crown.']
# ['The bird has two large wingbars and a small bill that is black.']
# ['This is a brown and white bird with a brown bill and a point on the inner rect']
# ['This bird is brown in color with a brown beak and brown eye rings.']
# ['This bird has wings that are black and has a yellow belly.']
# ['The bird is red with a black beak and grey wings.']
# ['This bird has wings blue and has a yellow body.']
# ['This bird has a long neck, a brown back and a red eye.']
# ['This bird has a small grey bill with a beige tip with white body and black feet']
# ['The bird has a yellow belly, small bill and striped wingbar.']
# ['A small round fluffy bird that has an orange mohawk.']
# ['This bird has wings that are grey and has a red belly.']
# ['This is a large grey bird with a long neck and a large pointed beak.']
# ['The bird has white throat, breast, belly and abdomen and brown beak, wings,']
# ['This small bird is mostly grey and white, with a dark crown, black short bill and']

# %%
filenames = ["Ready2Paraphrase.txt", "paraphrase_all_captions.txt"]

with open("All_Captions.txt", "w") as outfile:
    for filename in filenames:
        with open(filename) as infile:
            contents = infile.read()
            outfile.write(contents)

# %%
# !pip install spacy==1.8.0
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\spacy_9ef07ac46d9540a8b94bc353ae7a156d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\spacy_9ef07ac46d9540a8b94bc353ae7a156d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Asus\AppData\Local\Temp\pip-wheel-dod7u4u7'
#        cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\spacy_9ef07ac46d9540a8b94bc353ae7a156d\
#   Complete output (368 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\spacy
#   copying spacy\about.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\compat.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\deprecated.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\language.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lemmatizer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\scorer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\train.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\util.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__init__.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__main__.py -> build\lib.win-amd64-3.8\spacy
#   creating build\lib.win-amd64-3.8\spacy\data
#   copying spacy\data\__init__.py -> build\lib.win-amd64-3.8\spacy\data
#   creating build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\convert.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\download.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\info.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\link.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\model.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\package.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\train.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\__init__.py -> build\lib.win-amd64-3.8\spacy\cli
#   creating build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\__init__.py -> build\lib.win-amd64-3.8\spacy\tokens
#   creating build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\download.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\language_data.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\morph_rules.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\tag_map.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\word_sets.py -> build\lib.win-amd64-3.8\spacy\en
#   copying spacy\en\__init__.py -> build\lib.win-amd64-3.8\spacy\en
#   creating build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\download.py -> build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\language_data.py -> build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\stop_words.py -> build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\tag_map.py -> build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\de
#   copying spacy\de\__init__.py -> build\lib.win-amd64-3.8\spacy\de
# Collecting spacy==1.8.0
#   Downloading spacy-1.8.0.tar.gz (3.3 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==1.8.0) (1.21.4)
# Collecting murmurhash<0.27,>=0.26
#   Downloading murmurhash-0.26.4.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cymem<1.32,>=1.30
#   Downloading cymem-1.31.2.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting preshed<2.0.0,>=1.0.0
#   Downloading preshed-1.0.1.tar.gz (112 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting thinc<6.6.0,>=6.5.0
#   Downloading thinc-6.5.2.tar.gz (926 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting plac<1.0.0,>=0.9.6
#   Downloading plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==1.8.0) (1.16.0)
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: ujson>=1.35 in c:\users\asus\anaconda3\lib\site-packages (from spacy==1.8.0) (4.0.2)
# Collecting dill<0.3,>=0.2
#   Downloading dill-0.2.9.tar.gz (150 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==1.8.0) (2.26.0)
# Collecting regex==2017.4.5
#   Downloading regex-2017.04.05.tar.gz (601 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==1.8.0) (2.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==1.8.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==1.8.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==1.8.0) (1.26.7)
# Requirement already satisfied: wrapt in c:\users\asus\appdata\roaming\python\python38\site-packages (from thinc<6.6.0,>=6.5.0->spacy==1.8.0) (1.13.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\asus\anaconda3\lib\site-packages (from thinc<6.6.0,>=6.5.0->spacy==1.8.0) (4.62.3)
# Collecting cytoolz<0.9,>=0.8
#   Downloading cytoolz-0.8.2.tar.gz (386 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: termcolor in c:\users\asus\appdata\roaming\python\python38\site-packages (from thinc<6.6.0,>=6.5.0->spacy==1.8.0) (1.1.0)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from cytoolz<0.9,>=0.8->thinc<6.6.0,>=6.5.0->spacy==1.8.0) (0.11.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<6.6.0,>=6.5.0->spacy==1.8.0) (0.4.4)
# Building wheels for collected packages: spacy, regex, cymem, dill, murmurhash, preshed, thinc, cytoolz
#   Building wheel for spacy (setup.py): started
#   Building wheel for spacy (setup.py): finished with status 'error'
#   Running setup.py clean for spacy
#   Building wheel for regex (setup.py): started
#   Building wheel for regex (setup.py): finished with status 'done'
#   Created wheel for regex: filename=regex-2017.4.5-cp38-cp38-win_amd64.whl size=240014 sha256=6177c9000266d2b2efd5e5c8fd3d4a03ec07db598e9ef3dbfd4cb66ad32fc7b8
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\45\6d\d9\1c9b861321c9240122cb967b734a80545c9f465be4fcb16f19
#   Building wheel for cymem (setup.py): started
#   Building wheel for cymem (setup.py): finished with status 'done'
#   Created wheel for cymem: filename=cymem-1.31.2-cp38-cp38-win_amd64.whl size=27566 sha256=4edaa91965732c22f4e2de43197099428607ad39275ef64de23d06e56950c00d
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\7d\79\cb\1a676ab9c2ea1be46f7d4ce7c687dac4aac9d45ee9935ed6e3
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.2.9-py3-none-any.whl size=77482 sha256=862f1580dfae8552bb4f1897ad6c04bf7f0ff42e4ddbaf98563826d8c07de6e9
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\da\03\f6\41ff217c2d88b1446b2d593d5b7433b9e823f1ee52e798e4f2
#   Building wheel for murmurhash (setup.py): started
#   Building wheel for murmurhash (setup.py): finished with status 'done'
#   Created wheel for murmurhash: filename=murmurhash-0.26.4-cp38-cp38-win_amd64.whl size=16145 sha256=6c20f93baf489124db5dfeef06e2602a8453ef832e8d15d9126dce6acfbbc057
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\a5\0b\1a\cbddc80a3e398dbffef76110dc751872d2e2dada63f6baaff2
#   Building wheel for preshed (setup.py): started
#   Building wheel for preshed (setup.py): finished with status 'done'
#   Created wheel for preshed: filename=preshed-1.0.1-cp38-cp38-win_amd64.whl size=93664 sha256=49d64a5d647c2fabd5644303b18856733280268de80f0300bc3ea4a040ddd628
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\49\19\ca\7c61cfaa11914a9f562cd0d1f3ee745c049d1eef08d458e995
#   Building wheel for thinc (setup.py): started
#   Building wheel for thinc (setup.py): finished with status 'error'
#   Running setup.py clean for thinc
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'error'
#   Running setup.py clean for cytoolz
# Successfully built regex cymem dill murmurhash preshed
# Failed to build spacy thinc cytoolz
# Installing collected packages: cymem, preshed, plac, pathlib, murmurhash, dill, cytoolz, thinc, regex, spacy
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.6
#     Uninstalling cymem-2.0.6:
#       Successfully uninstalled cymem-2.0.6
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.6
#     Uninstalling preshed-3.0.6:
#       Successfully uninstalled preshed-3.0.6
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.7
#     Uninstalling murmurhash-1.0.7:
#       Successfully uninstalled murmurhash-1.0.7
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.3
#     Uninstalling dill-0.3.3:
#       Successfully uninstalled dill-0.3.3
#   Attempting uninstall: cytoolz
#     Found existing installation: cytoolz 0.11.0
#     Uninstalling cytoolz-0.11.0:
#       Successfully uninstalled cytoolz-0.11.0
#     Running setup.py install for cytoolz: started
#     Running setup.py install for cytoolz: finished with status 'error'
#   Rolling back uninstall of cytoolz
#   Moving to c:\users\asus\anaconda3\lib\site-packages\cytoolz-0.11.0-py3.8.egg-info
#    from C:\Users\Asus\anaconda3\Lib\site-packages\~ytoolz-0.11.0-py3.8.egg-info
#   Moving to c:\users\asus\anaconda3\lib\site-packages\cytoolz\
#    from C:\Users\Asus\anaconda3\Lib\site-packages\~ytoolz
#   creating build\lib.win-amd64-3.8\spacy\zh
#   copying spacy\zh\__init__.py -> build\lib.win-amd64-3.8\spacy\zh
#   creating build\lib.win-amd64-3.8\spacy\es
#   copying spacy\es\language_data.py -> build\lib.win-amd64-3.8\spacy\es
#   copying spacy\es\stop_words.py -> build\lib.win-amd64-3.8\spacy\es
#   copying spacy\es\tag_map.py -> build\lib.win-amd64-3.8\spacy\es
#   copying spacy\es\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\es
#   copying spacy\es\__init__.py -> build\lib.win-amd64-3.8\spacy\es
#   creating build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\language_data.py -> build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\punctuation.py -> build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\stop_words.py -> build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.8\spacy\fr
#   copying spacy\fr\__init__.py -> build\lib.win-amd64-3.8\spacy\fr
#   creating build\lib.win-amd64-3.8\spacy\it
#   copying spacy\it\language_data.py -> build\lib.win-amd64-3.8\spacy\it
#   copying spacy\it\stop_words.py -> build\lib.win-amd64-3.8\spacy\it
#   copying spacy\it\__init__.py -> build\lib.win-amd64-3.8\spacy\it
#   creating build\lib.win-amd64-3.8\spacy\hu
#   copying spacy\hu\language_data.py -> build\lib.win-amd64-3.8\spacy\hu
#   copying spacy\hu\punctuation.py -> build\lib.win-amd64-3.8\spacy\hu
#   copying spacy\hu\stop_words.py -> build\lib.win-amd64-3.8\spacy\hu
#   copying spacy\hu\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\hu
#   copying spacy\hu\__init__.py -> build\lib.win-amd64-3.8\spacy\hu
#   creating build\lib.win-amd64-3.8\spacy\pt
#   copying spacy\pt\language_data.py -> build\lib.win-amd64-3.8\spacy\pt
#   copying spacy\pt\stop_words.py -> build\lib.win-amd64-3.8\spacy\pt
#   copying spacy\pt\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\pt
#   copying spacy\pt\__init__.py -> build\lib.win-amd64-3.8\spacy\pt
#   creating build\lib.win-amd64-3.8\spacy\nl
#   copying spacy\nl\language_data.py -> build\lib.win-amd64-3.8\spacy\nl
#   copying spacy\nl\stop_words.py -> build\lib.win-amd64-3.8\spacy\nl
#   copying spacy\nl\__init__.py -> build\lib.win-amd64-3.8\spacy\nl
#   creating build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\language_data.py -> build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\lemma_rules.py -> build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\morph_rules.py -> build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\stop_words.py -> build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\sv
#   copying spacy\sv\__init__.py -> build\lib.win-amd64-3.8\spacy\sv
#   creating build\lib.win-amd64-3.8\spacy\fi
#   copying spacy\fi\language_data.py -> build\lib.win-amd64-3.8\spacy\fi
#   copying spacy\fi\stop_words.py -> build\lib.win-amd64-3.8\spacy\fi
#   copying spacy\fi\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\fi
#   copying spacy\fi\__init__.py -> build\lib.win-amd64-3.8\spacy\fi
#   creating build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\language_data.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\lemma_rules.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\morph_rules.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\punctuation.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\stop_words.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\tag_map.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\bn
#   copying spacy\bn\__init__.py -> build\lib.win-amd64-3.8\spacy\bn
#   creating build\lib.win-amd64-3.8\spacy\he
#   copying spacy\he\language_data.py -> build\lib.win-amd64-3.8\spacy\he
#   copying spacy\he\stop_words.py -> build\lib.win-amd64-3.8\spacy\he
#   copying spacy\he\__init__.py -> build\lib.win-amd64-3.8\spacy\he
#   creating build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_adverbs_irreg.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_nouns.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_verbs.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   copying spacy\en\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\en\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conllu2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\__init__.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   creating build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\abbreviations.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\emoticons.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\entity_rules.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\punctuation.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\tag_map.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\util.py -> build\lib.win-amd64-3.8\spacy\language_data
#   copying spacy\language_data\__init__.py -> build\lib.win-amd64-3.8\spacy\language_data
#   creating build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\__init__.py -> build\lib.win-amd64-3.8\spacy\serialize
#   creating build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\__init__.py -> build\lib.win-amd64-3.8\spacy\syntax
#   creating build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\align_raw.py -> build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\read_conll.py -> build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\read_ner.py -> build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\read_ontonotes.py -> build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\read_ptb.py -> build\lib.win-amd64-3.8\spacy\munge
#   copying spacy\munge\__init__.py -> build\lib.win-amd64-3.8\spacy\munge
#   creating build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\conftest.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_attrs.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_download.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_orth.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_pickles.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\util.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\__init__.py -> build\lib.win-amd64-3.8\spacy\tests
#   creating build\lib.win-amd64-3.8\spacy\tests\matcher
#   copying spacy\tests\matcher\test_entity_id.py -> build\lib.win-amd64-3.8\spacy\tests\matcher
#   copying spacy\tests\matcher\test_matcher.py -> build\lib.win-amd64-3.8\spacy\tests\matcher
#   copying spacy\tests\matcher\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\matcher
#   creating build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_ner.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_nonproj.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_noun_chunks.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse_navigate.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_sbd.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_sbd_prag.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_space_attachment.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   creating build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_codecs.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_huffman.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_io.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_packer.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialization.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   creating build\lib.win-amd64-3.8\spacy\tests\spans
#   copying spacy\tests\spans\test_merge.py -> build\lib.win-amd64-3.8\spacy\tests\spans
#   copying spacy\tests\spans\test_span.py -> build\lib.win-amd64-3.8\spacy\tests\spans
#   copying spacy\tests\spans\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\spans
#   creating build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_freeze_string_store.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_stringstore.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   creating build\lib.win-amd64-3.8\spacy\tests\tagger
#   copying spacy\tests\tagger\test_lemmatizer.py -> build\lib.win-amd64-3.8\spacy\tests\tagger
#   copying spacy\tests\tagger\test_morph_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\tagger
#   copying spacy\tests\tagger\test_spaces.py -> build\lib.win-amd64-3.8\spacy\tests\tagger
#   copying spacy\tests\tagger\test_tag_names.py -> build\lib.win-amd64-3.8\spacy\tests\tagger
#   copying spacy\tests\tagger\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\tagger
#   creating build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_urls.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_whitespace.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   creating build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_add_entities.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_array.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_doc_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_noun_chunks.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_token_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   creating build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\test_similarity.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\test_vectors.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   creating build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_add_vectors.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_lexeme.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_vocab_api.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\attrs.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\cfile.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\gold.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lexeme.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\matcher.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\morphology.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\orth.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\parts_of_speech.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\pipeline.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\strings.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\symbols.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tagger.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tokenizer.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\typedefs.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\vocab.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\attrs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\cfile.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\gold.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lexeme.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\morphology.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\orth.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\parts_of_speech.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\pipeline.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\strings.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\structs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\symbols.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tagger.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tokenizer.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\typedefs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\vocab.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__init__.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tokens\doc.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\span.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\token.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\doc.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\span.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\token.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\__init__.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\serialize\bits.pyx -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\huffman.pyx -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\packer.pyx -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\bits.pxd -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\huffman.pxd -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\packer.pxd -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\serialize\__init__.pxd -> build\lib.win-amd64-3.8\spacy\serialize
#   copying spacy\syntax\arc_eager.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\beam_parser.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\iterators.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\ner.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nonproj.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\parser.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\stateclass.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\transition_system.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_parse_features.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_state.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\arc_eager.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\beam_parser.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\iterators.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\ner.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nonproj.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\parser.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\stateclass.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\transition_system.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_parse_features.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_state.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\__init__.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\tests\tokenizer\sun.txt -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   running build_ext
#   building 'spacy.parts_of_speech' extension
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   creating build\temp.win-amd64-3.8\Release\spacy
#   C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\gcc.exe -mdll -O -Wall -DMS_WIN64 -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\spacy_9ef07ac46d9540a8b94bc353ae7a156d\include -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\anaconda3\include -c spacy/parts_of_speech.cpp -o build\temp.win-amd64-3.8\Release\spacy\parts_of_speech.o -O3 -Wno-strict-prototypes -Wno-unused-function
#   cc1plus.exe: warning: command line option '-Wno-strict-prototypes' is valid for C/ObjC but not for C++
#   writing build\temp.win-amd64-3.8\Release\spacy\parts_of_speech.cp38-win_amd64.def
#   C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\g++.exe -shared -s build\temp.win-amd64-3.8\Release\spacy\parts_of_speech.o build\temp.win-amd64-3.8\Release\spacy\parts_of_speech.cp38-win_amd64.def -LC:\Users\Asus\anaconda3\libs -LC:\Users\Asus\anaconda3\PCbuild\amd64 -lpython38 -lmsvcr140 -o build\lib.win-amd64-3.8\spacy\parts_of_speech.cp38-win_amd64.pyd
#   building 'spacy.strings' extension
#   C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\gcc.exe -mdll -O -Wall -DMS_WIN64 -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\spacy_9ef07ac46d9540a8b94bc353ae7a156d\include -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\anaconda3\include -c spacy/strings.cpp -o build\temp.win-amd64-3.8\Release\spacy\strings.o -O3 -Wno-strict-prototypes -Wno-unused-function
#   cc1plus.exe: warning: command line option '-Wno-strict-prototypes' is valid for C/ObjC but not for C++
#   spacy/strings.cpp: In function 'PyObject* PyInit_strings()':
#   spacy/strings.cpp:5025:42: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings_StringStore.tp_print = 0;
#                                             ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp:5025:42: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings_StringStore.tp_print = 0;
#                                             ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp:5025:42: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings_StringStore.tp_print = 0;
#                                             ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp:5080:59: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings___pyx_scope_struct____iter__.tp_print = 0;
#                                                              ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp:5080:59: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings___pyx_scope_struct____iter__.tp_print = 0;
#                                                              ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp:5080:59: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5spacy_7strings___pyx_scope_struct____iter__.tp_print = 0;
#                                                              ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from spacy/strings.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   spacy/strings.cpp: In function 'void __Pyx_ExceptionSwap(PyObject**, PyObject**, PyObject**)':
#   spacy/strings.cpp:7228:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   spacy/strings.cpp:7229:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   spacy/strings.cpp:7230:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   spacy/strings.cpp:7231:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = *type;
#                ^~~~~~~~
#                curexc_type
#   spacy/strings.cpp:7232:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = *value;
#                ^~~~~~~~~
#                curexc_value
#   spacy/strings.cpp:7233:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = *tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   error: command 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin\\gcc.exe' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for spacy
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\thinc_97a2cb91c8e443c9af14e4a80f8563f9\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\thinc_97a2cb91c8e443c9af14e4a80f8563f9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Asus\AppData\Local\Temp\pip-wheel-vbpu16p_'
#        cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\thinc_97a2cb91c8e443c9af14e4a80f8563f9\
#   Complete output (541 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\thinc
#   copying thinc\about.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\api.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\check.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\describe.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\exceptions.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\loss.py -> build\lib.win-amd64-3.8\thinc
#   copying thinc\__init__.py -> build\lib.win-amd64-3.8\thinc
#   creating build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\conftest.py -> build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\strategies.py -> build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\test_api_funcs.py -> build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\test_util.py -> build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\util.py -> build\lib.win-amd64-3.8\thinc\tests
#   copying thinc\tests\__init__.py -> build\lib.win-amd64-3.8\thinc\tests
#   creating build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_about.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_affine.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_check_exceptions.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_difference.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_hash_embed.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_imports.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_loss.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_mem.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_model.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_ops.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\test_pooling.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   copying thinc\tests\unit\__init__.py -> build\lib.win-amd64-3.8\thinc\tests\unit
#   creating build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_affine_learns.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_basic_tagger.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_batch_norm.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_feed_forward.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_mnist.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\test_shape_check.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   copying thinc\tests\integration\__init__.py -> build\lib.win-amd64-3.8\thinc\tests\integration
#   creating build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\__init__.py -> build\lib.win-amd64-3.8\thinc\linear
#   creating build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\id2vec.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\mem.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\pooling.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\train.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\util.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\vec2vec.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\vecs2vec.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\vecs2vecs.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_lsuv.py -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\__init__.py -> build\lib.win-amd64-3.8\thinc\neural
#   creating build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\datasets.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\load_nlp.py -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\__init__.py -> build\lib.win-amd64-3.8\thinc\extra
#   creating build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\affine.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\batchnorm.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\convolution.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\difference.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\elu.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\embed.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\feed_forward.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\hash_embed.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\lstm.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\maxout.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\model.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\relu.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\resnet.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\softmax.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\static_vectors.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   copying thinc\neural\_classes\__init__.py -> build\lib.win-amd64-3.8\thinc\neural\_classes
#   creating build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_datasets.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_data_utils.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_generic_utils.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\__init__.py -> build\lib.win-amd64-3.8\thinc\extra\_vendorized
#   copying thinc\linalg.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\structs.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\typedefs.pyx -> build\lib.win-amd64-3.8\thinc
#   copying thinc\linalg.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\structs.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\typedefs.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\__init__.pxd -> build\lib.win-amd64-3.8\thinc
#   copying thinc\compile_time_constants.pxi -> build\lib.win-amd64-3.8\thinc
#   copying thinc\linear\avgtron.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\features.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\linear.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\serialize.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\sparse.pyx -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\avgtron.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\features.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\serialize.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\sparse.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\linear\__init__.pxd -> build\lib.win-amd64-3.8\thinc\linear
#   copying thinc\neural\ops.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\optimizers.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_funcs.pyx -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\_funcs.pxd -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\neural\__init__.pxd -> build\lib.win-amd64-3.8\thinc\neural
#   copying thinc\extra\cache.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\eg.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\mb.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\search.pyx -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\cache.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\eg.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\mb.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\search.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   copying thinc\extra\__init__.pxd -> build\lib.win-amd64-3.8\thinc\extra
#   running build_ext
#   building 'thinc.linalg' extension
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   creating build\temp.win-amd64-3.8\Release\thinc
#   C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\gcc.exe -mdll -O -Wall -DMS_WIN64 -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\thinc_97a2cb91c8e443c9af14e4a80f8563f9\include -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\anaconda3\include -c thinc/linalg.cpp -o build\temp.win-amd64-3.8\Release\thinc\linalg.o -O3 -Wno-strict-prototypes -Wno-unused-function
#   cc1plus.exe: warning: command line option '-Wno-strict-prototypes' is valid for C/ObjC but not for C++
#   thinc/linalg.cpp: In function 'PyObject* PyInit_linalg()':
#   thinc/linalg.cpp:4200:36: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5thinc_6linalg_Matrix.tp_print = 0;
#                                       ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from thinc/linalg.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   thinc/linalg.cpp:4200:36: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5thinc_6linalg_Matrix.tp_print = 0;
#                                       ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from thinc/linalg.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   thinc/linalg.cpp:4200:36: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5thinc_6linalg_Matrix.tp_print = 0;
#                                       ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from thinc/linalg.cpp:4:
#   C:\Users\Asus\anaconda3\include/cpython/object.h:260:63: note: declared here
#        Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#                                                                  ^
#   thinc/linalg.cpp:4220:33: warning: '_typeobject::tp_print' is deprecated [-Wdeprecated-declarations]
#      __pyx_type_5thinc_6linalg_Vec.tp_print = 0;
#                                    ^~~~~~~~
#   In file included from C:\Users\Asus\anaconda3\include/object.h:746,
#                    from C:\Users\Asus\anaconda3\include/pytime.h:6,
#                    from C:\Users\Asus\anaconda3\include/Python.h:85,
#                    from thinc/linalg.cpp:4:
# ...
#   cytoolz/dicttoolz.c:9054:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        *value = tstate->exc_value;
#                         ^~~~~~~~~
#                         curexc_value
#   cytoolz/dicttoolz.c:9055:19: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        *tb = tstate->exc_traceback;
#                      ^~~~~~~~~~~~~
#                      curexc_traceback
#   cytoolz/dicttoolz.c: In function '__Pyx__ExceptionReset':
#   cytoolz/dicttoolz.c:9062:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   cytoolz/dicttoolz.c:9063:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   cytoolz/dicttoolz.c:9064:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   cytoolz/dicttoolz.c:9065:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = type;
#                ^~~~~~~~
#                curexc_type
#   cytoolz/dicttoolz.c:9066:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = value;
#                ^~~~~~~~~
#                curexc_value
#   cytoolz/dicttoolz.c:9067:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   cytoolz/dicttoolz.c: In function '__Pyx__GetException':
#   cytoolz/dicttoolz.c:9122:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   cytoolz/dicttoolz.c:9123:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   cytoolz/dicttoolz.c:9124:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   cytoolz/dicttoolz.c:9125:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = local_type;
#                ^~~~~~~~
#                curexc_type
#   cytoolz/dicttoolz.c:9126:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = local_value;
#                ^~~~~~~~~
#                curexc_value
#   cytoolz/dicttoolz.c:9127:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = local_tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   cytoolz/dicttoolz.c: In function '__Pyx_ImportType':
#   cytoolz/dicttoolz.c:10565:81: warning: unknown conversion type character 'z' in format [-Wformat=]
#                "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                                                                                    ^
#   cytoolz/dicttoolz.c:10565:90: warning: unknown conversion type character 'z' in format [-Wformat=]
#                "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                                                                                             ^
#   cytoolz/dicttoolz.c:10565:13: warning: too many arguments for format [-Wformat-extra-args]
#                "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   error: command 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin\\gcc.exe' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for cytoolz
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\cytoolz_facace86617149c492ad7f63e9b5269d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\cytoolz_facace86617149c492ad7f63e9b5269d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Asus\AppData\Local\Temp\pip-record-ar4iy76d\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Asus\anaconda3\Include\cytoolz'
#          cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-ok761dgv\cytoolz_facace86617149c492ad7f63e9b5269d\
#     Complete output (132 lines):
#     running install
#     C:\Users\Asus\AppData\Roaming\Python\Python38\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.8
#     creating build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\compatibility.py -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\utils_test.py -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\_signatures.py -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\_version.py -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\__init__.py -> build\lib.win-amd64-3.8\cytoolz
#     creating build\lib.win-amd64-3.8\cytoolz\curried
#     copying cytoolz\curried\exceptions.py -> build\lib.win-amd64-3.8\cytoolz\curried
#     copying cytoolz\curried\operator.py -> build\lib.win-amd64-3.8\cytoolz\curried
#     copying cytoolz\curried\__init__.py -> build\lib.win-amd64-3.8\cytoolz\curried
#     copying cytoolz\dicttoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\functoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\itertoolz.pyx -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\recipes.pyx -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\utils.pyx -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\cpython.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\dicttoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\functoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\itertoolz.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\recipes.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\utils.pxd -> build\lib.win-amd64-3.8\cytoolz
#     copying cytoolz\__init__.pxd -> build\lib.win-amd64-3.8\cytoolz
#     creating build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\dev_skip_test.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_compatibility.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_curried.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_curried_toolzlike.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_dev_skip_test.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_dicttoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_docstrings.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_doctests.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_embedded_sigs.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_functoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_inspect_args.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_itertoolz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_none_safe.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_recipes.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_serialization.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_signatures.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_tlz.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     copying cytoolz\tests\test_utils.py -> build\lib.win-amd64-3.8\cytoolz\tests
#     running build_ext
#     building 'cytoolz.dicttoolz' extension
#     creating build\temp.win-amd64-3.8
#     creating build\temp.win-amd64-3.8\Release
#     creating build\temp.win-amd64-3.8\Release\cytoolz
#     C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\gcc.exe -mdll -O -Wall -DMS_WIN64 -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\anaconda3\include -c cytoolz/dicttoolz.c -o build\temp.win-amd64-3.8\Release\cytoolz\dicttoolz.o
#     cytoolz/dicttoolz.c: In function '__Pyx_PyCFunction_FastCall':
#     cytoolz/dicttoolz.c:8277:13: error: too many arguments to function '(PyObject * (*)(PyObject *, PyObject * const*, Py_ssize_t))meth'
#          return (*((__Pyx_PyCFunctionFast)meth)) (self, args, nargs, NULL);
#                 ~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     cytoolz/dicttoolz.c: In function '__Pyx__ExceptionSave':
#     cytoolz/dicttoolz.c:9053:21: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#          *type = tstate->exc_type;
#                          ^~~~~~~~
#                          curexc_type
#     cytoolz/dicttoolz.c:9054:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#          *value = tstate->exc_value;
#                           ^~~~~~~~~
#                           curexc_value
#     cytoolz/dicttoolz.c:9055:19: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#          *tb = tstate->exc_traceback;
#                        ^~~~~~~~~~~~~
#                        curexc_traceback
#     cytoolz/dicttoolz.c: In function '__Pyx__ExceptionReset':
#     cytoolz/dicttoolz.c:9062:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#          tmp_type = tstate->exc_type;
#                             ^~~~~~~~
#                             curexc_type
#     cytoolz/dicttoolz.c:9063:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#          tmp_value = tstate->exc_value;
#                              ^~~~~~~~~
#                              curexc_value
#     cytoolz/dicttoolz.c:9064:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#          tmp_tb = tstate->exc_traceback;
#                           ^~~~~~~~~~~~~
#                           curexc_traceback
#     cytoolz/dicttoolz.c:9065:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#          tstate->exc_type = type;
#                  ^~~~~~~~
#                  curexc_type
#     cytoolz/dicttoolz.c:9066:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#          tstate->exc_value = value;
#                  ^~~~~~~~~
#                  curexc_value
#     cytoolz/dicttoolz.c:9067:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#          tstate->exc_traceback = tb;
#                  ^~~~~~~~~~~~~
#                  curexc_traceback
#     cytoolz/dicttoolz.c: In function '__Pyx__GetException':
#     cytoolz/dicttoolz.c:9122:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#          tmp_type = tstate->exc_type;
#                             ^~~~~~~~
#                             curexc_type
#     cytoolz/dicttoolz.c:9123:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#          tmp_value = tstate->exc_value;
#                              ^~~~~~~~~
#                              curexc_value
#     cytoolz/dicttoolz.c:9124:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#          tmp_tb = tstate->exc_traceback;
#                           ^~~~~~~~~~~~~
#                           curexc_traceback
#     cytoolz/dicttoolz.c:9125:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#          tstate->exc_type = local_type;
#                  ^~~~~~~~
#                  curexc_type
#     cytoolz/dicttoolz.c:9126:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#          tstate->exc_value = local_value;
#                  ^~~~~~~~~
#                  curexc_value
#     cytoolz/dicttoolz.c:9127:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#          tstate->exc_traceback = local_tb;
#                  ^~~~~~~~~~~~~
#                  curexc_traceback
#     cytoolz/dicttoolz.c: In function '__Pyx_ImportType':
#     cytoolz/dicttoolz.c:10565:81: warning: unknown conversion type character 'z' in format [-Wformat=]
#                  "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                                                                                      ^
#     cytoolz/dicttoolz.c:10565:90: warning: unknown conversion type character 'z' in format [-Wformat=]
#                  "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                                                                                               ^
#     cytoolz/dicttoolz.c:10565:13: warning: too many arguments for format [-Wformat-extra-args]
#                  "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     error: command 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin\\gcc.exe' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\cytoolz_facace86617149c492ad7f63e9b5269d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-ok761dgv\\cytoolz_facace86617149c492ad7f63e9b5269d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Asus\AppData\Local\Temp\pip-record-ar4iy76d\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Asus\anaconda3\Include\cytoolz' Check the logs for full command output.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-1.2.0/en_core_web_md-1.2.0.tar.gz
# Out:
# ^C

# %%
pip install spacy==2.0.0
# Out:
# Collecting spacy==2.0.0Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Asus\AppData\Local\Temp\pip-wheel-n13op0sk'
#        cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-zendflhu\spacy_e83d5eae92bb4c5191bad6a99891845d\
#   Complete output (675 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\spacy
#   copying spacy\about.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\compat.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\glossary.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\language.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lemmatizer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\scorer.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\util.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\_ml.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__init__.py -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__main__.py -> build\lib.win-amd64-3.8\spacy
#   creating build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\convert.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\download.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\evaluate.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\info.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\link.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\package.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\profile.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\train.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\validate.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\vocab.py -> build\lib.win-amd64-3.8\spacy\cli
#   copying spacy\cli\__init__.py -> build\lib.win-amd64-3.8\spacy\cli
#   creating build\lib.win-amd64-3.8\spacy\data
#   copying spacy\data\__init__.py -> build\lib.win-amd64-3.8\spacy\data
#   creating build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\render.py -> build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\templates.py -> build\lib.win-amd64-3.8\spacy\displacy
#   copying spacy\displacy\__init__.py -> build\lib.win-amd64-3.8\spacy\displacy
#   creating build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\char_classes.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\entity_rules.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang
#   copying spacy\lang\__init__.py -> build\lib.win-amd64-3.8\spacy\lang
#   creating build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\__init__.py -> build\lib.win-amd64-3.8\spacy\syntax
#   creating build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\conftest.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_matcher.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_misc.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_pickles.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\test_underscore.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\util.py -> build\lib.win-amd64-3.8\spacy\tests
#   copying spacy\tests\__init__.py -> build\lib.win-amd64-3.8\spacy\tests
#   creating build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\printers.py -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\underscore.py -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\__init__.py -> build\lib.win-amd64-3.8\spacy\tokens
#   creating build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conllu2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\conll_ner2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\iob2json.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   copying spacy\cli\converters\__init__.py -> build\lib.win-amd64-3.8\spacy\cli\converters
#   creating build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   copying spacy\lang\bn\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\bn
#   creating build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\examples.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   Downloading spacy-2.0.0.tar.gz (13.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==2.0.0) (1.21.4)
# Collecting murmurhash<0.29,>=0.28
#   Downloading murmurhash-0.28.0.tar.gz (23 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (1.0.1)
# Collecting thinc<6.11.0,>=6.10.0
#   Downloading thinc-6.10.3.tar.gz (1.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (0.9.6)
#   copying spacy\lang\da\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   copying spacy\lang\da\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\da
#   creating build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\examples.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   copying spacy\lang\de\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\de
#   creating build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\examples.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   copying spacy\lang\en\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\en
#   creating build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\examples.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   copying spacy\lang\es\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\es
#   creating build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   copying spacy\lang\fi\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\fi
#   creating build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\examples.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   copying spacy\lang\fr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\fr
#   creating build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\irish_morphology_helpers.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   copying spacy\lang\ga\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ga
#   creating build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\examples.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   copying spacy\lang\he\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\he
#   creating build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   copying spacy\lang\hi\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hi
#   creating build\lib.win-amd64-3.8\spacy\lang\hr
#   copying spacy\lang\hr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hr
#   copying spacy\lang\hr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hr
#   creating build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\examples.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   copying spacy\lang\hu\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\hu
#   creating build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\examples.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\norm_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\punctuation.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\syntax_iterators.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   copying spacy\lang\id\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\id
#   creating build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\examples.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   copying spacy\lang\it\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\it
#   creating build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\examples.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   copying spacy\lang\ja\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ja
#   creating build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\examples.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   copying spacy\lang\nb\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\nb
#   creating build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   copying spacy\lang\nl\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\nl
#   creating build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\examples.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   copying spacy\lang\pl\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\pl
#   creating build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\examples.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\lemmatizer.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\lex_attrs.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   copying spacy\lang\pt\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\pt
#   creating build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   copying spacy\lang\ro\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\ro
#   creating build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\examples.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\morph_rules.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   copying spacy\lang\sv\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\sv
#   creating build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\tag_map.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   copying spacy\lang\th\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\th
#   creating build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\stop_words.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\tokenizer_exceptions.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   copying spacy\lang\tr\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\tr
#   creating build\lib.win-amd64-3.8\spacy\lang\xx
#   copying spacy\lang\xx\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\xx
#   creating build\lib.win-amd64-3.8\spacy\lang\zh
#   copying spacy\lang\zh\examples.py -> build\lib.win-amd64-3.8\spacy\lang\zh
#   copying spacy\lang\zh\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\zh
#   creating build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\lookup.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\en\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\lookup.py -> build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\__init__.py -> build\lib.win-amd64-3.8\spacy\lang\sv\lemmatizer
#   creating build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_add_entities.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_array.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_creation.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_doc_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_pickle_doc.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_span.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_span_merge.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\test_token_api.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   copying spacy\tests\doc\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\doc
#   creating build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\test_biluo.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\test_lev_align.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   copying spacy\tests\gold\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\gold
#   creating build\lib.win-amd64-3.8\spacy\tests\lang
#   copying spacy\tests\lang\test_attrs.py -> build\lib.win-amd64-3.8\spacy\tests\lang
#   copying spacy\tests\lang\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang
#   creating build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_add_label.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_beam_parse.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_ner.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_neural_parser.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_nn_beam.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_nonproj.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_parse_navigate.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_preset_sbd.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_space_attachment.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\test_to_from_bytes_disk.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   copying spacy\tests\parser\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\parser
#   creating build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_pipe_methods.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_textcat.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   copying spacy\tests\pipeline\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\pipeline
#   creating build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue118.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1242.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1250.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1253.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1257.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1305.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1375.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1380.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1387.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1434.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1450.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1488.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue242.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue309.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue351.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue360.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue361.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue401.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue429.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue514.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue54.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue587.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue588.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue589.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue590.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue595.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue599.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue600.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue615.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue686.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue693.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue704.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue717.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue719.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue736.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue740.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue743.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue744.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue758.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue759.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue768.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue775.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue781.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue792.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue801.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue805.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue834.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue850.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue852.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue859.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue886.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue891.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue903.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue910.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue912.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue957.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue995.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\test_issue999.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   copying spacy\tests\regression\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\regression
#   creating build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialization.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_empty_model.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_extension_attrs.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_parser_ner.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_stringstore.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tagger.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tensorizer.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_vocab.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   copying spacy\tests\serialize\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\serialize
#   creating build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_freeze_string_store.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_stringstore.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   copying spacy\tests\stringstore\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\stringstore
#   creating build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_naughty_strings.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_urls.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_whitespace.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   creating build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\test_similarity.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\test_vectors.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   copying spacy\tests\vectors\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\vectors
#   creating build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_add_vectors.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_lexeme.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\test_vocab_api.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   copying spacy\tests\vocab\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\vocab
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\bn
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_text.py -> build\lib.win-amd64-3.8\spacy\tests\lang\da
#   copying spacy\tests\lang\da\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\da
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_lemma.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_models.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_parser.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_text.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   copying spacy\tests\lang\de\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\de
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_customized_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_indices.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_lemmatizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_models.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_ner.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_noun_chunks.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_parser.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_punct.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_sbd.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_tagger.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_text.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   copying spacy\tests\lang\en\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\en
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\es
#   copying spacy\tests\lang\es\test_exception.py -> build\lib.win-amd64-3.8\spacy\tests\lang\es
#   copying spacy\tests\lang\es\test_text.py -> build\lib.win-amd64-3.8\spacy\tests\lang\es
#   copying spacy\tests\lang\es\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\es
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\fi
#   copying spacy\tests\lang\fi\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fi
#   copying spacy\tests\lang\fi\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fi
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_exceptions.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_lemmatization.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_text.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\fr
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\ga
#   copying spacy\tests\lang\ga\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\ga
#   copying spacy\tests\lang\ga\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\ga
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\he
#   copying spacy\tests\lang\he\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\he
#   copying spacy\tests\lang\he\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\he
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\hu
#   copying spacy\tests\lang\hu\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\hu
#   copying spacy\tests\lang\hu\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\hu
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\id
#   copying spacy\tests\lang\id\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.8\spacy\tests\lang\id
#   copying spacy\tests\lang\id\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\id
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\ja
#   copying spacy\tests\lang\ja\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\ja
#   copying spacy\tests\lang\ja\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\ja
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\nb
#   copying spacy\tests\lang\nb\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\nb
#   copying spacy\tests\lang\nb\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\nb
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\sv
#   copying spacy\tests\lang\sv\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\sv
#   copying spacy\tests\lang\sv\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\sv
#   creating build\lib.win-amd64-3.8\spacy\tests\lang\th
#   copying spacy\tests\lang\th\test_tokenizer.py -> build\lib.win-amd64-3.8\spacy\tests\lang\th
#   copying spacy\tests\lang\th\__init__.py -> build\lib.win-amd64-3.8\spacy\tests\lang\th
#   copying spacy\attrs.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\gold.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lexeme.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\matcher.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\morphology.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\parts_of_speech.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\pipeline.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\strings.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\symbols.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\tokenizer.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\typedefs.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\vectors.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\vocab.pyx -> build\lib.win-amd64-3.8\spacy
#   copying spacy\attrs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\gold.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\lexeme.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\morphology.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\parts_of_speech.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\pipeline.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\strings.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\structs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\symbols.pxd -> build\lib.win-amd64-3.8\spacy
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==2.0.0) (1.16.0)
# Requirement already satisfied: pathlib in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (1.0.1)
# Requirement already satisfied: ujson>=1.35 in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (4.0.2)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy==2.0.0) (0.2.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy==2.0.0) (2.26.0)
# Collecting regex==2017.4.5
#   Using cached regex-2017.4.5-cp38-cp38-win_amd64.whl
# Collecting ftfy<5.0.0,>=4.4.2
#   Downloading ftfy-4.4.3.tar.gz (50 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting msgpack-python
#   Downloading msgpack-python-0.5.6.tar.gz (138 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting msgpack-numpy
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: html5lib in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy==2.0.0) (1.1)
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy==2.0.0) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.0) (2.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.0.0) (1.26.7)
# Collecting msgpack<1.0.0,>=0.5.6
#   Downloading msgpack-0.6.2.tar.gz (119 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cytoolz<0.10,>=0.9.0
#   Downloading cytoolz-0.9.0.1.tar.gz (443 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wrapt<1.11.0,>=1.10.0
#   Downloading wrapt-1.10.11.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\asus\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.0->spacy==2.0.0) (4.62.3)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\asus\anaconda3\lib\site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.0->spacy==2.0.0) (0.11.2)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<6.11.0,>=6.10.0->spacy==2.0.0) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\asus\anaconda3\lib\site-packages (from html5lib->ftfy<5.0.0,>=4.4.2->spacy==2.0.0) (0.5.1)
# Building wheels for collected packages: spacy, ftfy, murmurhash, thinc, msgpack-python, cytoolz, msgpack, wrapt
#   Building wheel for spacy (setup.py): started
#   Building wheel for spacy (setup.py): finished with status 'error'
#   Running setup.py clean for spacy
#   Building wheel for ftfy (setup.py): started
#   Building wheel for ftfy (setup.py): finished with status 'done'
#   Created wheel for ftfy: filename=ftfy-4.4.3-py3-none-any.whl size=41082 sha256=07864aaab5b2ccc7ad839eced04031c7a8dee5d90357785fb65764f9b20003a7
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\97\ea\83\0ea1632b87aa8a3ecdc2c3914d7dc786ed2ff37eb9e9242f3a
#   Building wheel for murmurhash (setup.py): started
#   Building wheel for murmurhash (setup.py): finished with status 'done'
#   Created wheel for murmurhash: filename=murmurhash-0.28.0-cp38-cp38-win_amd64.whl size=16392 sha256=2ad117d00a533ceb2b4395680b084d3af0192e9f18fed00b05074c2758a7eeee
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\c4\94\18\da70ce5a85c38612b346994f18e348e28e8c6006f6b2daf784
#   Building wheel for thinc (setup.py): started
#   Building wheel for thinc (setup.py): finished with status 'done'
#   Created wheel for thinc: filename=thinc-6.10.3-cp38-cp38-win_amd64.whl size=2078568 sha256=aa8995bbd9fb478e3f90be95c997925304db04b840140c96cd72616246c5cc2a
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\fb\8a\f0\814ec96cace85b0afd73928e7c6396f270d6a61443c9b1ff57
#   Building wheel for msgpack-python (setup.py): started
#   Building wheel for msgpack-python (setup.py): finished with status 'done'
#   Created wheel for msgpack-python: filename=msgpack_python-0.5.6-cp38-cp38-win_amd64.whl size=92709 sha256=5f2dd008b7b7e97693cb48f001e584f19fbf2692ae30c706d7a07839d329260e
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\03\7f\e7\8ec405fe5220fe1401be3dfa943f6e1f10b525f54f68d75e0a
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'done'
#   Created wheel for cytoolz: filename=cytoolz-0.9.0.1-cp38-cp38-win_amd64.whl size=434687 sha256=7c8dcef84047089f41104e17c19ead6b182a10ecb1bd15d90f1317be9e79a155
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\6f\49\e5\c1170703a39737d0b37581805c6d5b8cb99a430814e52c7a07
#   Building wheel for msgpack (setup.py): started
#   Building wheel for msgpack (setup.py): finished with status 'done'
#   Created wheel for msgpack: filename=msgpack-0.6.2-cp38-cp38-win_amd64.whl size=79434 sha256=e01186cf70ffffe9e525d6e6fa66a7e4ac60c1d38a712e85aa0c0a61d2ad94ee
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\5d\f2\04\0d19c10080b996bef17c908a6243e6e65d8da1a4094a3f604d
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.10.11-cp38-cp38-win_amd64.whl size=35106 sha256=413ba1f11036f05d2a2836862a8b13ea04f367d12acd436f45481552ca96ae91
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\93\8e\c9\a18fa0021f99d9e55a3ce5f2adc4c14b1dd1cab385e6993e2b
# Successfully built ftfy murmurhash thinc msgpack-python cytoolz msgpack wrapt
# Failed to build spacy
# Installing collected packages: msgpack, wrapt, murmurhash, msgpack-numpy, cytoolz, thinc, regex, msgpack-python, ftfy, spacy
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.2
#     Uninstalling msgpack-1.0.2:
#       Successfully uninstalled msgpack-1.0.2
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 0.26.4
#     Uninstalling murmurhash-0.26.4:
#       Successfully uninstalled murmurhash-0.26.4
#   Attempting uninstall: cytoolz
#     Found existing installation: cytoolz 0.11.0
#     Uninstalling cytoolz-0.11.0:
#       Successfully uninstalled cytoolz-0.11.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.16
#     Uninstalling thinc-8.0.16:
#       Successfully uninstalled thinc-8.0.16
#   Attempting uninstall: regex
#     Found existing installation: regex 2021.8.3
#     Uninstalling regex-2021.8.3:
#       Successfully uninstalled regex-2021.8.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.3.0
#     Uninstalling spacy-3.3.0:
#       Successfully uninstalled spacy-3.3.0
#     Running setup.py install for spacy: started
#     Running setup.py install for spacy: finished with status 'error'
#   Rolling back uninstall of spacy
#   Moving to c:\users\asus\anaconda3\lib\site-packages\spacy-3.3.0.dist-info\
#    from C:\Users\Asus\anaconda3\Lib\site-packages\~pacy-3.3.0.dist-info
#   Moving to c:\users\asus\anaconda3\lib\site-packages\spacy\
#    from C:\Users\Asus\anaconda3\Lib\site-packages\~pacy
#   Moving to c:\users\asus\anaconda3\scripts\spacy.exe
#    from C:\Users\Asus\AppData\Local\Temp\pip-uninstall-j5fgcx6t\spacy.exe
#   copying spacy\tokenizer.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\typedefs.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\vocab.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\__init__.pxd -> build\lib.win-amd64-3.8\spacy
#   copying spacy\syntax\arc_eager.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\ner.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nn_parser.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nonproj.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\stateclass.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\transition_system.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_beam_utils.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_state.pyx -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\arc_eager.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\ner.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nn_parser.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\nonproj.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\stateclass.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\transition_system.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\_state.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\syntax\__init__.pxd -> build\lib.win-amd64-3.8\spacy\syntax
#   copying spacy\tokens\doc.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\span.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\token.pyx -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\doc.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\span.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\token.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tokens\__init__.pxd -> build\lib.win-amd64-3.8\spacy\tokens
#   copying spacy\tests\tokenizer\sun.txt -> build\lib.win-amd64-3.8\spacy\tests\tokenizer
#   running build_ext
#   building 'spacy.parts_of_speech' extension
#   creating build\temp.win-amd64-3.8
#   creating build\temp.win-amd64-3.8\Release
#   creating build\temp.win-amd64-3.8\Release\spacy
# ...
#                                                                  ^
#   spacy/strings.cpp: In function 'void __Pyx__ExceptionSave(PyThreadState*, PyObject**, PyObject**, PyObject**)':
#   spacy/strings.cpp:7128:21: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        *type = tstate->exc_type;
#                        ^~~~~~~~
#                        curexc_type
#   spacy/strings.cpp:7129:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        *value = tstate->exc_value;
#                         ^~~~~~~~~
#                         curexc_value
#   spacy/strings.cpp:7130:19: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        *tb = tstate->exc_traceback;
#                      ^~~~~~~~~~~~~
#                      curexc_traceback
#   spacy/strings.cpp: In function 'void __Pyx__ExceptionReset(PyThreadState*, PyObject*, PyObject*, PyObject*)':
#   spacy/strings.cpp:7137:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   spacy/strings.cpp:7138:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   spacy/strings.cpp:7139:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   spacy/strings.cpp:7140:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = type;
#                ^~~~~~~~
#                curexc_type
#   spacy/strings.cpp:7141:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = value;
#                ^~~~~~~~~
#                curexc_value
#   spacy/strings.cpp:7142:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   spacy/strings.cpp: In function 'int __Pyx__GetException(PyThreadState*, PyObject**, PyObject**, PyObject**)':
#   spacy/strings.cpp:7187:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   spacy/strings.cpp:7188:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   spacy/strings.cpp:7189:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   spacy/strings.cpp:7190:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = local_type;
#                ^~~~~~~~
#                curexc_type
#   spacy/strings.cpp:7191:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = local_value;
#                ^~~~~~~~~
#                curexc_value
#   spacy/strings.cpp:7192:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = local_tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   spacy/strings.cpp: In function 'void __Pyx__ExceptionSwap(PyThreadState*, PyObject**, PyObject**, PyObject**)':
#   spacy/strings.cpp:8361:24: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tmp_type = tstate->exc_type;
#                           ^~~~~~~~
#                           curexc_type
#   spacy/strings.cpp:8362:25: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tmp_value = tstate->exc_value;
#                            ^~~~~~~~~
#                            curexc_value
#   spacy/strings.cpp:8363:22: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tmp_tb = tstate->exc_traceback;
#                         ^~~~~~~~~~~~~
#                         curexc_traceback
#   spacy/strings.cpp:8364:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_type'; did you mean 'curexc_type'?
#        tstate->exc_type = *type;
#                ^~~~~~~~
#                curexc_type
#   spacy/strings.cpp:8365:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_value'; did you mean 'curexc_value'?
#        tstate->exc_value = *value;
#                ^~~~~~~~~
#                curexc_value
#   spacy/strings.cpp:8366:13: error: 'PyThreadState' {aka 'struct _ts'} has no member named 'exc_traceback'; did you mean 'curexc_traceback'?
#        tstate->exc_traceback = *tb;
#                ^~~~~~~~~~~~~
#                curexc_traceback
#   spacy/strings.cpp: In function 'PyTypeObject* __Pyx_ImportType(const char*, const char*, size_t, int)':
#   spacy/strings.cpp:9265:13: warning: unknown conversion type character 'z' in format [-Wformat=]
#                "%s.%s size changed, may indicate binary incompatibility. Expected %zd, got %zd",
#                ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#   spacy/strings.cpp:9265:13: warning: unknown conversion type character 'z' in format [-Wformat=]
#   spacy/strings.cpp:9265:13: warning: too many arguments for format [-Wformat-extra-args]
#   error: command 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin\\gcc.exe' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for spacy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Asus\AppData\Local\Temp\pip-record-pc8mcpx2\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Asus\anaconda3\Include\spacy'
#          cwd: C:\Users\Asus\AppData\Local\Temp\pip-install-zendflhu\spacy_e83d5eae92bb4c5191bad6a99891845d\
#     Complete output (12 lines):
#     running install
#     C:\Users\Asus\AppData\Roaming\Python\Python38\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     running build_ext
#     building 'spacy.parts_of_speech' extension
#     C:\Program Files\mingw-w64\x86_64-8.1.0-posix-seh-rt_v6-rev0\mingw64\bin\gcc.exe -mdll -O -Wall -DMS_WIN64 -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\AppData\Local\Temp\pip-install-zendflhu\spacy_e83d5eae92bb4c5191bad6a99891845d\include -IC:\Users\Asus\anaconda3\include -IC:\Users\Asus\anaconda3\include -c spacy/parts_of_speech.cpp -o build\temp.win-amd64-3.8\Release\spacy\parts_of_speech.o -O3 -Wno-strict-prototypes -Wno-unused-function
#     gcc: error: spacy/parts_of_speech.cpp: No such file or directory
#     gcc: fatal error: no input files
#     compilation terminated.
#     error: command 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin\\gcc.exe' failed with exit status 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\Asus\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Asus\\AppData\\Local\\Temp\\pip-install-zendflhu\\spacy_e83d5eae92bb4c5191bad6a99891845d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Asus\AppData\Local\Temp\pip-record-pc8mcpx2\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\Asus\anaconda3\Include\spacy' Check the logs for full command output.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_md-1.2.0/en_core_web_md-1.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-1.2.0/en_core_web_md-1.2.0.tar.gz (1086.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting spacy<2.0.0,>=1.7.0
#   Downloading spacy-1.10.1.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.21.4)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.26.4)
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.0.1)
# Collecting thinc<6.6.0,>=6.5.0
#   Using cached thinc-6.5.2.tar.gz (926 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.9.6)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.16.0)
# Requirement already satisfied: pathlib in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.0.1)
# Requirement already satisfied: ujson>=1.35 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (4.0.2)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.2.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (2.26.0)
# Collecting regex<2017.12.1,>=2017.4.1
#   Downloading regex-2017.11.09.tar.gz (608 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ftfy<5.0.0,>=4.4.2
#   Using cached ftfy-4.4.3-py3-none-any.whl
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.2.5)
# Requirement already satisfied: html5lib in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.1)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\asus\\anaconda3\\lib\\site-packages\\murmurhash-0.26.4.dist-info\\METADATA'
#
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_md-1.2.0/en_core_web_md-1.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-1.2.0/en_core_web_md-1.2.0.tar.gz (1086.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting spacy<2.0.0,>=1.7.0
#   Using cached spacy-1.10.1.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.7 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.21.4)
# Requirement already satisfied: murmurhash<0.27,>=0.26 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.26.4)
# Requirement already satisfied: cymem<1.32,>=1.30 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.31.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.0.1)
# Collecting thinc<6.6.0,>=6.5.0
#   Using cached thinc-6.5.2.tar.gz (926 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.9.6)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.16.0)
# Requirement already satisfied: pathlib in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.0.1)
# Requirement already satisfied: ujson>=1.35 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (4.0.2)
# Requirement already satisfied: dill<0.3,>=0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.2.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (2.26.0)
# Collecting regex<2017.12.1,>=2017.4.1
#   Using cached regex-2017.11.09.tar.gz (608 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ftfy<5.0.0,>=4.4.2
#   Using cached ftfy-4.4.3-py3-none-any.whl
# Requirement already satisfied: html5lib in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (1.1)
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from ftfy<5.0.0,>=4.4.2->spacy<2.0.0,>=1.7.0->en-core-web-md==1.2.0) (0.2.5)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\asus\\anaconda3\\lib\\site-packages\\murmurhash-0.26.4.dist-info\\METADATA'
#
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import os
import math
import torch
import datetime
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F

from torch import nn
from spacy.lang.en import English
from torchvision import transforms
from torchvision.models import inception_v3
from torch.utils.data import Dataset, DataLoader

# %%
DATASETS_PATH = 'D:/498R/New folder/dataset/CUB'

# %%
CUB_200_2011_PATH = os.path.join(DATASETS_PATH, 'cub_200_2011_all_caps.txt')

# %%
CUB_200_2011_METADATA_PATH           = os.path.join(CUB_200_2011_PATH, 'metadata.pth')
CUB_200_2011_IMG_ID_TO_CAPS_PATH     = os.path.join(CUB_200_2011_PATH, 'cub_200_2011_img_id_to_caps.pth')

# %%
with open(os.path.join(DATASETS_PATH, 'cub_200_2011_all_caps.txt'), 'r') as f:
    def __init__(self, split='all', d_image_size=64, transform=None, should_pad=False, pad_to_length=None, no_start_end=False, **kwargs):
        super().__init__()

        assert split in ('all', 'train_val', 'test')
        assert d_image_size in (64, 128, 256)
        if should_pad:
            assert pad_to_length >= 3 # <START> foo <END> need at least length 3.

        self.split = split
        self.d_image_size = d_image_size
        self.transform = transform
        self.should_pad = should_pad
        self.pad_to_length = pad_to_length
        self.no_start_end = no_start_end

        metadata = torch.load(CUB_200_2011_METADATA_PATH)

        # labels
        self.img_id_to_class_id = metadata['img_id_to_class_id']
        self.class_id_to_class_name = metadata['class_id_to_class_name']
        self.class_name_to_class_id = metadata['class_name_to_class_id']

        # captions
        self.img_id_to_encoded_caps = metadata['img_id_to_encoded_caps']
        self.word_id_to_word = metadata['word_id_to_word']
        self.word_to_word_id = metadata['word_to_word_id']
        self.pad_token     = self.word_to_word_id['<PAD>']
        self.start_token   = self.word_to_word_id['<START>']
        self.end_token     = self.word_to_word_id['<END>']
        self.unknown_token = self.word_to_word_id['<UNKNOWN>']

        self.d_vocab = metadata['num_words']
        self.num_captions_per_image = metadata['num_captions_per_image']

        nlp = English()
        self.tokenizer = nlp.Defaults.create_tokenizer(nlp) # Create a Tokenizer with the default settings for English including punctuation rules and exceptions

        # images
        if split == 'all':
            self.img_ids = metadata['img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_IMGS_256_PATH
        elif split == 'train_val':
            self.img_ids = metadata['train_val_img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_256_PATH
        else:
            self.img_ids = metadata['test_img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_TEST_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_TEST_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_TEST_IMGS_256_PATH

        self.imgs = torch.load(imgs_path)
        assert self.imgs.size()[1:] == (3, d_image_size, d_image_size) and self.imgs.dtype == torch.uint8

    def encode_caption(self, cap):
        words = [token.text for token in self.tokenizer(cap)]
        return [self.word_to_word_id.get(word, self.unknown_token) for word in words]

    def decode_caption(self, cap):
        if isinstance(cap, torch.Tensor):
            cap = cap.tolist()
        return ' '.join([self.word_id_to_word[word_id] for word_id in cap])

    def pad_caption(self, cap):
        max_len = self.pad_to_length - 2 # 2 since we need a start token and an end token.
        cap = cap[:max_len] # truncate to maximum length.
        cap = [self.start_token] + cap + [self.end_token]
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def pad_without_start_end(self, cap):
        cap = cap[:self.pad_to_length] # truncate to maximum length.
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        img = self.imgs[idx]
        if self.transform:
            img = self.transform(img)
        img_id = self.img_ids[idx]
        class_id = self.img_id_to_class_id[img_id]
        encoded_caps = self.img_id_to_encoded_caps[img_id]
        cap_idx = torch.randint(low=0, high=self.num_captions_per_image, size=(1,)).item()
        encoded_cap = encoded_caps[cap_idx]
        if self.should_pad:
            if self.no_start_end:
                encoded_cap, cap_len = self.pad_without_start_end(encoded_cap)
            else:
                encoded_cap, cap_len = self.pad_caption(encoded_cap)
            return img, class_id, encoded_cap, cap_len
        return img, class_id, encoded_cap

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3214-FAD0
#
#  Directory of C:\Users\Asus
#
# 05/25/2022  03:11 PM    <DIR>          .
# 12/17/2021  03:31 AM    <DIR>          ..
# 09/22/2021  11:15 PM    <DIR>          .anaconda
# 08/01/2021  11:44 AM    <DIR>          .astropy
# 12/24/2021  02:33 AM             9,026 .bash_history
# 03/22/2022  02:08 AM    <DIR>          .cache
# 12/05/2021  01:41 AM    <DIR>          .conda
# 05/16/2021  07:28 PM                25 .condarc
# 05/16/2021  07:28 PM    <DIR>          .continuum
# 11/06/2021  05:51 PM    <DIR>          .fiftyone
# 05/17/2021  01:21 PM               168 .gitconfig
# 02/24/2020  01:48 PM    <DIR>          .idlerc
# 03/22/2022  02:06 AM    <DIR>          .ipynb_checkpoints
# 05/16/2021  04:57 PM    <DIR>          .ipython
# 05/23/2021  09:41 PM    <DIR>          .jupyter
# 05/17/2021  11:20 AM    <DIR>          .keras
# 05/16/2021  07:28 PM    <DIR>          .matplotlib
# 06/12/2021  12:53 PM    <DIR>          .vscode
# 08/16/2021  06:19 PM             6,899 -1.14-windows.xml
# 05/25/2021  02:45 AM    <DIR>          3D Objects
# 08/23/2021  01:20 AM         7,980,982 abc.npz
# 12/11/2021  08:57 PM    <DIR>          anaconda3
# 12/17/2021  10:39 AM    <DIR>          Contacts
# 07/24/2021  04:55 PM    <DIR>          Desktop
# 05/26/2021  02:01 PM    <DIR>          Documents
# 05/25/2022  12:53 AM    <DIR>          Downloads
# 12/17/2021  10:39 AM    <DIR>          Favorites
# 11/06/2021  06:26 PM    <DIR>          fiftyone
# 11/25/2021  06:52 PM    <DIR>          keras
# 12/17/2021  10:39 AM    <DIR>          Links
# 03/18/2020  02:51 PM    <DIR>          Microsoft
# 05/19/2022  09:45 PM    <DIR>          Motor-Imagery-Tasks-Classification-using-EEG-data-master
# 12/17/2021  10:39 AM    <DIR>          Music
# 10/16/2021  05:41 PM    <DIR>          neural_sequence_labeling
# 05/20/2022  09:24 AM    <DIR>          OneDrive
# 10/30/2021  02:15 PM    <DIR>          Praat
# 10/16/2021  06:58 PM    <DIR>          Punctuation-Restoration-main
# 12/15/2021  12:16 PM    <DIR>          PycharmProjects
# 08/23/2019  01:22 PM    <DIR>          Roaming
# 12/17/2021  10:39 AM    <DIR>          Saved Games
# 12/17/2021  10:39 AM    <DIR>          Searches
# 05/25/2022  03:11 PM           788,598 text.ipynb
# 11/25/2021  02:31 PM             4,204 text2image.ipynb
# 05/25/2022  03:11 PM            36,477 utils.py
# 12/17/2021  10:39 AM    <DIR>          Videos
#                8 File(s)      8,826,379 bytes
#               37 Dir(s)  161,470,832,640 bytes free

# %%
import torch
import matplotlib.pyplot as plt
# from utils import get_cub_200_2011
from torchvision.utils import make_grid

# %%
#  utils

import os
import math
import torch
import datetime
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F

from torch import nn
from spacy.lang.en import English
from torchvision import transforms
from torchvision.models import inception_v3
from torch.utils.data import Dataset, DataLoader

DATASETS_PATH = 'C:\\Users\Asus\kaggle\input'

# CUB_200_2011
# CUB_200_2011_PATH = os.path.join(DATASETS_PATH, 'cub-200-2011')
CUB_200_2011_PATH = DATASETS_PATH +'\cub-200-2011'
# Captions and metadata
CUB_200_2011_METADATA_PATH           = CUB_200_2011_PATH + '\metadata.pth'
CUB_200_2011_METADATA_PATH           = CUB_200_2011_PATH + '\metadata.pth'

CUB_200_2011_IMG_ID_TO_CAPS_PATH     = CUB_200_2011_PATH + 'cub_200_2011_img_id_to_caps.pth'
# All images
CUB_200_2011_IMGS_64_PATH            = CUB_200_2011_PATH + '\imgs_64x64.pth'
CUB_200_2011_IMGS_128_PATH           = CUB_200_2011_PATH + '\imgs_128x128.pth'
CUB_200_2011_IMGS_256_PATH           = CUB_200_2011_PATH + '\imgs_256x256.pth'
# Training/Validation split images
CUB_200_2011_TRAIN_VAL_IMGS_64_PATH  = CUB_200_2011_PATH + '\imgs_train_val_64x64.pth'
CUB_200_2011_TRAIN_VAL_IMGS_128_PATH = CUB_200_2011_PATH + '\imgs_train_val_128x128.pth'
CUB_200_2011_TRAIN_VAL_IMGS_256_PATH = CUB_200_2011_PATH + '\imgs_train_val_256x256.pth'
# Testing split images
CUB_200_2011_TEST_IMGS_64_PATH       = CUB_200_2011_PATH + '\imgs_test_64x64.pth'
CUB_200_2011_TEST_IMGS_128_PATH      = CUB_200_2011_PATH + '\imgs_test_128x128.pth'
CUB_200_2011_TEST_IMGS_256_PATH      = CUB_200_2011_PATH + '\imgs_test_256x256.pth'
# GLOVE word embeddings for CUB 200 2011
CUB_200_2011_GLOVE_PATH = CUB_200_2011_PATH + 'glove_relevant_embeddings.pth'
CUB_200_2011_D_VOCAB = 1750

# OXFORD_FLOWERS_102
OXFORD_FLOWERS_102_PATH = os.path.join(DATASETS_PATH, 'oxford-flowers-102')
OXFORD_FLOWERS_102_IMG_ID_TO_CAPS_PATH     = os.path.join(OXFORD_FLOWERS_102_PATH, 'oxford_flowers_102_img_id_to_caps.pth')
# Captions and metadata
OXFORD_FLOWERS_102_METADATA_PATH           = os.path.join(OXFORD_FLOWERS_102_PATH, 'metadata.pth')
# All images
OXFORD_FLOWERS_102_IMGS_64_PATH            = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_64x64.pth')
OXFORD_FLOWERS_102_IMGS_128_PATH           = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_128x128.pth')
OXFORD_FLOWERS_102_IMGS_256_PATH           = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_256x256.pth')
# Training/Validation split images
OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_64_PATH  = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_train_val_64x64.pth')
OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_128_PATH = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_train_val_128x128.pth')
OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_256_PATH = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_train_val_256x256.pth')
# Testing split images
OXFORD_FLOWERS_102_TEST_IMGS_64_PATH       = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_test_64x64.pth')
OXFORD_FLOWERS_102_TEST_IMGS_128_PATH      = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_test_128x128.pth')
OXFORD_FLOWERS_102_TEST_IMGS_256_PATH      = os.path.join(OXFORD_FLOWERS_102_PATH, 'imgs_test_256x256.pth')

# EMNLP_2017_NEWS
EMNLP_2017_NEWS_PATH = os.path.join(DATASETS_PATH, 'emnlp-2017-news')
EMNLP_2017_NEWS_DATA_PATH = os.path.join(EMNLP_2017_NEWS_PATH, 'data.pth')
# EMNLP 2017 NEWS RAW
EMNLP_2017_NEWS_RAW_TRAIN_PATH = os.path.join(EMNLP_2017_NEWS_PATH, 'emnlp_train_set.pth')
EMNLP_2017_NEWS_RAW_VALID_PATH = os.path.join(EMNLP_2017_NEWS_PATH, 'emnlp_valid_set.pth')
EMNLP_2017_NEWS_RAW_TEST_PATH  = os.path.join(EMNLP_2017_NEWS_PATH, 'emnlp_test_set.pth')

# WIKITEXT 103
WIKITEXT_103_PATH = os.path.join(DATASETS_PATH, 'wikitext_103')
WIKITEXT_103_RAW_TRAIN_PATH = os.path.join(WIKITEXT_103_PATH, 'wikitext_train_set.pth')
WIKITEXT_103_RAW_VALID_PATH = os.path.join(WIKITEXT_103_PATH, 'wikitext_valid_set.pth')
WIKITEXT_103_RAW_TEST_PATH  = os.path.join(WIKITEXT_103_PATH, 'wikitext_test_set.pth')

# GLOVE 300 DIM EMBEDDINGS OF 5102 WORDS (from scratchgan paper)
GLOVE_5102_300_PATH = os.path.join(DATASETS_PATH, 'glove-300-dimensional-embeddings-for-5102-words', 'glove_5102_300.pth')

# CUB 200 2011, OXFORD FLOWERS 102, EMNLP 2017 AND WIKITEXT 103 COMBINED VOCAB
COMBINED_WORD_FREQ_PATH = os.path.join(DATASETS_PATH, 'cub_oxford_emnlp_wikitext_word_freqs.pth')
WORD_ID_TO_WORD_5K_PATH = os.path.join(DATASETS_PATH, 'combined-vocab', 'word_id_to_word_5k.pth')
WORD_ID_TO_WORD_10K_PATH = os.path.join(DATASETS_PATH, 'combined-vocab', 'word_id_to_word_10k.pth')

# QUORA PARAPHRASE DATASET
QUORA_PARAPHRASE_PATH = os.path.join(DATASETS_PATH, 'quora-paraphrase')
QUORA_PARAPHRASE_DATA_PATH = os.path.join(QUORA_PARAPHRASE_PATH, 'quora_paraphrase.pth')

class CUB_200_2011(Dataset):
    """If should_pad is True, need to also provide a pad_to_length. Padding also adds <START> and <END> tokens to captions."""
    def __init__(self, split='all', d_image_size=64, transform=None, should_pad=False, pad_to_length=None, no_start_end=False, **kwargs):
        # super().__init__()
        DATASETS_PATH = 'C:\\Users\Asus\kaggle\input'

        # CUB_200_2011
        # CUB_200_2011_PATH = os.path.join(DATASETS_PATH, 'cub-200-2011')
        CUB_200_2011_PATH = DATASETS_PATH + '\cub-200-2011'
        # Captions and metadata
        CUB_200_2011_METADATA_PATH = CUB_200_2011_PATH + '\metadata.pth'
        assert split in ('all', 'train_val', 'test')
        assert d_image_size in (64, 128, 256)
        if should_pad:
            assert pad_to_length >= 3 # <START> foo <END> need at least length 3.

        self.split = split
        self.d_image_size = d_image_size
        self.transform = transform
        self.should_pad = should_pad
        self.pad_to_length = pad_to_length
        self.no_start_end = no_start_end
        self.tt =0


        #jjj
        dd=0
        print(CUB_200_2011_METADATA_PATH)
        metadata = torch.load(CUB_200_2011_METADATA_PATH)

        # labels
        self.img_id_to_class_id = metadata['img_id_to_class_id']
        self.class_id_to_class_name = metadata['class_id_to_class_name']
        self.class_name_to_class_id = metadata['class_name_to_class_id']

        # captions
        self.img_id_to_encoded_caps = metadata['img_id_to_encoded_caps']
        self.word_id_to_word = metadata['word_id_to_word']
        self.word_to_word_id = metadata['word_to_word_id']
        self.pad_token     = self.word_to_word_id['<PAD>']
        self.start_token   = self.word_to_word_id['<START>']
        self.end_token     = self.word_to_word_id['<END>']
        self.unknown_token = self.word_to_word_id['<UNKNOWN>']

        self.d_vocab = metadata['num_words']
        self.num_captions_per_image = metadata['num_captions_per_image']

        nlp = English()
        self.tokenizer = nlp.Defaults.create_tokenizer(nlp) # Create a Tokenizer with the default settings for English including punctuation rules and exceptions

        # images
        if split == 'all':
            self.img_ids = metadata['img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_IMGS_256_PATH
        elif split == 'train_val':
            self.img_ids = metadata['train_val_img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_TRAIN_VAL_IMGS_256_PATH
        else:
            self.img_ids = metadata['test_img_ids']
            if d_image_size == 64:
                imgs_path = CUB_200_2011_TEST_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = CUB_200_2011_TEST_IMGS_128_PATH
            else:
                imgs_path = CUB_200_2011_TEST_IMGS_256_PATH

        self.imgs = torch.load(imgs_path)
        assert self.imgs.size()[1:] == (3, d_image_size, d_image_size) and self.imgs.dtype == torch.uint8

    def encode_caption(self, cap):
        words = [token.text for token in self.tokenizer(cap)]
        return [self.word_to_word_id.get(word, self.unknown_token) for word in words]

    def decode_caption(self, cap):
        if isinstance(cap, torch.Tensor):
            cap = cap.tolist()
        return ' '.join([self.word_id_to_word[word_id] for word_id in cap])

    def pad_caption(self, cap):
        max_len = self.pad_to_length - 2 # 2 since we need a start token and an end token.
        cap = cap[:max_len] # truncate to maximum length.
        cap = [self.start_token] + cap + [self.end_token]
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def pad_without_start_end(self, cap):
        cap = cap[:self.pad_to_length] # truncate to maximum length.
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        img = self.imgs[idx]
        if self.transform:
            img = self.transform(img)
        img_id = self.img_ids[idx]
        class_id = self.img_id_to_class_id[img_id]
        encoded_caps = self.img_id_to_encoded_caps[img_id]
        cap_idx = torch.randint(low=0, high=self.num_captions_per_image, size=(1,)).item()
        encoded_cap = encoded_caps[cap_idx]
        if self.should_pad:
            if self.no_start_end:
                encoded_cap, cap_len = self.pad_without_start_end(encoded_cap)
            else:
                encoded_cap, cap_len = self.pad_caption(encoded_cap)
            return img, class_id, encoded_cap, cap_len
        return img, class_id, encoded_cap

class OxfordFlowers102(Dataset):
    """If should_pad is True, need to also provide a pad_to_length. Padding also adds <START> and <END> tokens to captions."""
    def __init__(self, split='all', d_image_size=64, transform=None, should_pad=False, pad_to_length=None, no_start_end=False, **kwargs):
        super().__init__()

        assert split in ('all', 'train_val', 'test')
        assert d_image_size in (64, 128, 256)
        if should_pad:
            assert pad_to_length >= 3 # <START> foo <END> need at least length 3.

        self.split = split
        self.d_image_size = d_image_size
        self.transform = transform
        self.should_pad = should_pad
        self.pad_to_length = pad_to_length
        self.no_start_end = no_start_end

        metadata = torch.load(OXFORD_FLOWERS_102_METADATA_PATH)

        # labels
        self.img_id_to_class_id = metadata['img_id_to_class_id']
        # credit https://github.com/jimgoo/caffe-oxford102/blob/master/class_labels.py
        self.class_id_to_class_name = ['pink primrose', 'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea', 'english marigold', 'tiger lily', 'moon orchid', 'bird of paradise', 'monkshood', 'globe thistle', 'snapdragon', "colt's foot", 'king protea', 'spear thistle', 'yellow iris', 'globe-flower', 'purple coneflower', 'peruvian lily', 'balloon flower', 'giant white arum lily', 'fire lily', 'pincushion flower', 'fritillary', 'red ginger', 'grape hyacinth', 'corn poppy', 'prince of wales feathers', 'stemless gentian', 'artichoke', 'sweet william', 'carnation', 'garden phlox', 'love in the mist', 'mexican aster', 'alpine sea holly', 'ruby-lipped cattleya', 'cape flower', 'great masterwort', 'siam tulip', 'lenten rose', 'barbeton daisy', 'daffodil', 'sword lily', 'poinsettia', 'bolero deep blue', 'wallflower', 'marigold', 'buttercup', 'oxeye daisy', 'common dandelion', 'petunia', 'wild pansy', 'primula', 'sunflower', 'pelargonium', 'bishop of llandaff', 'gaura', 'geranium', 'orange dahlia', 'pink-yellow dahlia?', 'cautleya spicata', 'japanese anemone', 'black-eyed susan', 'silverbush', 'californian poppy', 'osteospermum', 'spring crocus', 'bearded iris', 'windflower', 'tree poppy', 'gazania', 'azalea', 'water lily', 'rose', 'thorn apple', 'morning glory', 'passion flower', 'lotus', 'toad lily', 'anthurium', 'frangipani', 'clematis', 'hibiscus', 'columbine', 'desert-rose', 'tree mallow', 'magnolia', 'cyclamen ', 'watercress', 'canna lily', 'hippeastrum ', 'bee balm', 'ball moss', 'foxglove', 'bougainvillea', 'camellia', 'mallow', 'mexican petunia', 'bromelia', 'blanket flower', 'trumpet creeper', 'blackberry lily']
        self.class_name_to_class_id = {c: i for i, c in enumerate(self.class_id_to_class_name)}

        # captions
        self.img_id_to_encoded_caps = metadata['img_id_to_encoded_caps']
        self.word_id_to_word = metadata['word_id_to_word']
        self.word_to_word_id = metadata['word_to_word_id']
        self.pad_token     = self.word_to_word_id['<PAD>']
        self.start_token   = self.word_to_word_id['<START>']
        self.end_token     = self.word_to_word_id['<END>']
        self.unknown_token = self.word_to_word_id['<UNKNOWN>']

        self.d_vocab = metadata['num_words']
        self.num_captions_per_image = metadata['num_captions_per_image']

        nlp = English()
        self.tokenizer = nlp.Defaults.create_tokenizer(nlp) # Create a Tokenizer with the default settings for English including punctuation rules and exceptions

        # images
        if split == 'all':
            self.img_ids = metadata['img_ids']
            if d_image_size == 64:
                imgs_path = OXFORD_FLOWERS_102_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = OXFORD_FLOWERS_102_IMGS_128_PATH
            else:
                imgs_path = OXFORD_FLOWERS_102_IMGS_256_PATH
        elif split == 'train_val':
            self.img_ids = metadata['train_val_img_ids']
            if d_image_size == 64:
                imgs_path = OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_128_PATH
            else:
                imgs_path = OXFORD_FLOWERS_102_TRAIN_VAL_IMGS_256_PATH
        else:
            self.img_ids = metadata['test_img_ids']
            if d_image_size == 64:
                imgs_path = OXFORD_FLOWERS_102_TEST_IMGS_64_PATH
            elif d_image_size == 128:
                imgs_path = OXFORD_FLOWERS_102_TEST_IMGS_128_PATH
            else:
                imgs_path = OXFORD_FLOWERS_102_TEST_IMGS_256_PATH

        self.imgs = torch.load(imgs_path)
        assert self.imgs.size()[1:] == (3, d_image_size, d_image_size) and self.imgs.dtype == torch.uint8

    def encode_caption(self, cap):
        words = [token.text for token in self.tokenizer(cap)]
        return [self.word_to_word_id.get(word, self.unknown_token) for word in words]

    def decode_caption(self, cap):
        if isinstance(cap, torch.Tensor):
            cap = cap.tolist()
        return ' '.join([self.word_id_to_word[word_id] for word_id in cap])

    def pad_caption(self, cap):
        max_len = self.pad_to_length - 2 # 2 since we need a start token and an end token.
        cap = cap[:max_len] # truncate to maximum length.
        cap = [self.start_token] + cap + [self.end_token]
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def pad_without_start_end(self, cap):
        cap = cap[:self.pad_to_length] # truncate to maximum length.
        cap_len = len(cap)
        padding = [self.pad_token]*(self.pad_to_length - cap_len)
        cap += padding
        return torch.tensor(cap, dtype=torch.long), cap_len

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        img = self.imgs[idx]
        if self.transform:
            img = self.transform(img)
        img_id = self.img_ids[idx]
        class_id = self.img_id_to_class_id[img_id]
        encoded_caps = self.img_id_to_encoded_caps[img_id]
        cap_idx = torch.randint(low=0, high=self.num_captions_per_image, size=(1,)).item()
        encoded_cap = encoded_caps[cap_idx]
        if self.should_pad:
            if self.no_start_end:
                encoded_cap, cap_len = self.pad_without_start_end(encoded_cap)
            else:
                encoded_cap, cap_len = self.pad_caption(encoded_cap)
            return img, class_id, encoded_cap, cap_len
        return img, class_id, encoded_cap

class EMNLP2017(Dataset):
    def __init__(self, dataset_path=EMNLP_2017_NEWS_DATA_PATH, split='train', **kwargs):
        assert split in ('train', 'valid', 'test')
        assert os.path.isfile(dataset_path)

        data = torch.load(dataset_path)

        self.split = split
        self.word_id_to_word = data['word_id_to_word']
        self.word_to_word_id = data['word_to_word_id']
        if split == 'train':
            self.seqs = data['train_data_sequences'].long()
            self.seq_lens = data['train_data_sequence_lengths'].long()
        elif split == 'valid':
            self.seqs = data['valid_data_sequences'].long()
            self.seq_lens = data['valid_data_sequence_lengths'].long()
        else:
            self.seqs = data['test_data_sequences'].long()
            self.seq_lens = data['test_data_sequence_lengths'].long()

        self.d_max_seq_len = self.seqs.size(1)
        self.d_vocab = len(self.word_id_to_word)
        self.pad_token = self.word_to_word_id[' ']
        self.unknown_token = self.word_to_word_id['<unk>']

    def encode(self, text):
        return [self.word_to_word_id.get(word, self.unknown_token) for word in text.split()]

    def decode(self, text):
        if isinstance(text, torch.Tensor):
            text = text.tolist()
        return ' '.join([self.word_id_to_word[word_id] for word_id in text])

    def __getitem__(self, idx):
        return self.seqs[idx], self.seq_lens[idx]

    def __len__(self):
        return len(self.seqs)

def to_one_hot(labels, d_classes):
    """
    Args:
        labels (Tensor): integer tensor of shape (d_batch, *)
        d_classes (int): number of classes
    Returns:
        (Tensor): float tensor of shape (d_batch, *, d_classes), one hot representation of the labels
    """
    return torch.zeros(*labels.size(), d_classes, device=labels.device).scatter_(-1, labels.unsqueeze(-1), 1)

def get_cub_200_2011(d_batch=4, should_pad=False, shuffle=True, **kwargs):
    transform = transforms.Lambda(lambda x: (x.float() / 255.) * 2. - 1.)
    print('hhh')
    train_set = CUB_200_2011(transform=transform, should_pad=should_pad, **kwargs)
    if not should_pad:
        def collate_fn(samples):
            imgs, class_ids, caps = zip(*samples)
            imgs = torch.stack(imgs)
            class_ids = torch.tensor(class_ids, dtype=torch.long)
            return imgs, class_ids, caps
        train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True, collate_fn=collate_fn)
    else:
        train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True)
    return train_set, train_loader

def get_oxford_flowers_102(d_batch=4, should_pad=False, shuffle=True, **kwargs):
    transform = transforms.Lambda(lambda x: (x.float() / 255.) * 2. - 1.)
    train_set = OxfordFlowers102(transform=transform, should_pad=should_pad, **kwargs)
    if not should_pad:
        def collate_fn(samples):
            imgs, class_ids, caps = zip(*samples)
            imgs = torch.stack(imgs)
            class_ids = torch.tensor(class_ids, dtype=torch.long)
            return imgs, class_ids, caps
        train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True, collate_fn=collate_fn)
    else:
        train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True)
    return train_set, train_loader

def get_emnlp_2017(d_batch=4, shuffle=True, **kwargs):
    dataset = EMNLP2017(**kwargs)
    loader = DataLoader(dataset, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True)
    return dataset, loader

###################################### TESTS ######################################

def test_get_cub_200_2011():
    train_set, train_loader = get_cub_200_2011(should_pad=True, pad_to_length=25)
    print('Size of vocabulary:', train_set.d_vocab)
    print('Number of images:', len(train_set))
    print('Number of batches:', len(train_loader))
    batch = next(iter(train_loader))
#     imgs, caps = batch
#     print(imgs.size(), imgs.dtype, imgs.max(), imgs.min())
#     print(caps)
    imgs, class_ids, caps, cap_lens = batch
    print(imgs.size(), imgs.dtype, imgs.min(), imgs.max())
    print(class_ids.size(), class_ids.dtype, class_ids)
    print(caps.size(), caps.dtype, caps)
    print(cap_lens.size(), cap_lens.dtype, cap_lens)
    for cap in caps:
        print(train_set.decode_caption(cap))

    # visualize
    denorm = transforms.Normalize((-1, -1, -1), (2, 2, 2))
    imgs = torch.stack([denorm(img) for img in imgs]).permute(0, 2, 3, 1).cpu()
    plt.figure(figsize=(1*8,4*8))
    for i, img in enumerate(imgs):
        plt.subplot(4, 1, i+1)
        plt.imshow(img)
        plt.axis('off')
        cap = train_set.decode_caption(caps[i])
        plt.title(cap)
    plt.suptitle('some images from the dataset')

def test_oxford_flowers_102():
    train_set, train_loader = get_oxford_flowers_102(should_pad=True, pad_to_length=25)
    print('Size of vocabulary:', train_set.d_vocab)
    print('Number of images:', len(train_set))
    print('Number of batches:', len(train_loader))
    batch = next(iter(train_loader))
#     imgs, caps = batch
#     print(imgs.size(), imgs.dtype, imgs.max(), imgs.min())
#     print(caps)
    imgs, class_ids, caps, cap_lens = batch
    print(imgs.size(), imgs.dtype, imgs.min(), imgs.max())
    print(class_ids.size(), class_ids.dtype, class_ids)
    print(caps.size(), caps.dtype, caps)
    print(cap_lens.size(), cap_lens.dtype, cap_lens)
    for cap in caps:
        print(train_set.decode_caption(cap))

    # visualize
    denorm = transforms.Normalize((-1, -1, -1), (2, 2, 2))
    imgs = torch.stack([denorm(img) for img in imgs]).permute(0, 2, 3, 1).cpu()
    plt.figure(figsize=(1*8,4*8))
    for i, img in enumerate(imgs):
        plt.subplot(4, 1, i+1)
        plt.imshow(img)
        plt.axis('off')
        cap = train_set.decode_caption(caps[i])
        plt.title(cap)
    plt.suptitle('some images from the dataset')

def test_get_emnlp_2017():
    d_batch = 16
    dataset, loader = get_emnlp_2017(d_batch=d_batch)
    batch = next(iter(loader))
    texts, text_lens = batch
    assert texts.size() == (d_batch, dataset.d_max_seq_len) and texts.dtype == torch.long
    assert text_lens.size() == (d_batch,) and text_lens.dtype == torch.long

def mkdir_p(path):
    """Make directory and all necessary parent directories given by the path."""
    os.makedirs(path, exist_ok=True)

def get_timestamp():
    """Return the current date and time in year, month, day, hour, minute and second format."""
    now = datetime.datetime.now()
    return now.strftime('%Y_%m_%d_%H_%M_%S')

def uniform_in_range(low=0., high=1., size=(1,), **kwargs):
    return (high - low) * torch.rand(*size, **kwargs) + low

def get_biased_coin(probability_of_heads=0.5):
    """Get a biased coin that returns True on heads."""
    return lambda: torch.rand(1).item() < probability_of_heads

def get_cub_200_2011_glove_embeddings(fine_tune=False):
    GLOVE_D_EMBED = 50
    glove_embeddings = torch.load(CUB_200_2011_GLOVE_PATH)
    assert glove_embeddings.size() == (CUB_200_2011_D_VOCAB, GLOVE_D_EMBED)
    assert glove_embeddings.dtype == torch.float
    embed = nn.Embedding(CUB_200_2011_D_VOCAB, GLOVE_D_EMBED)
    embed.weight == nn.Parameter(glove_embeddings)
    embed.weight.requires_grad = fine_tune

    return embed

def text_embeds_to_encoded_texts(text_embeds, ref_embeds):
    """
    Find closest words using euclidean distance.
    Args:
        text_embeds (Tensor): float tensor of shape (d_batch, d_max_seq_len, d_text_embed)
        ref_embeds (Tensor): float tensor of shape (d_vocab, d_text_embed)
    Returns:
        encoded_texts list(list(int)): list of list of word indices.
    """
    encoded_texts = []
    for text_embed in text_embeds:
        encoded_text = []
        for word_embed in text_embed:
            errs = (ref_embeds - word_embed.unsqueeze(0))
            dists = (errs**2).sum(dim=1)
            word_id = dists.argmin().item()
            encoded_text.append(word_id)
        encoded_texts.append(encoded_text)
    return encoded_texts

def damsm_loss(img_local_features, img_global_features, text_local_features, text_global_features, visualize=False, gamma_1=5.0, gamma_2=5.0, gamma_3=10.0):
    """
    Deep Attentional Multimodal Similarity Model (DAMSM) as given in AttnGAN paper (https://arxiv.org/pdf/1711.10485.pdf)
    Calculate the loss. (Based on https://github.com/taoxugit/AttnGAN/blob/master/code/miscc/losses.py)
    NOTE: d_common = d_text_feature
    Args:
        img_local_features (Tensor): float tensor of shape (d_batch, d_img_regions, d_common)
        img_global_features (Tensor): float tensor of shape (d_batch, d_common)
        text_local_features (Tensor): float tensor of shape (d_batch, d_max_seq_len, d_common)
        text_global_features (Tensor): float tensor of shape (d_batch, d_common)
    Returns:
        loss (Tensor): float tensor scalar.
    """
    device = img_local_features.device
    d_batch = img_local_features.size(0)
    R_Q_Ds = torch.empty(d_batch, d_batch, device=device)
    R_Q_D_globals = torch.empty(d_batch, d_batch, device=device)

    for i in range(d_batch):
        R_Q_Ds[i] = loss_helper(
            img_local_features,
            text_local_features[i].unsqueeze(0).repeat(d_batch, 1, 1),
            gamma_1=gamma_1, gamma_2=gamma_2
        )
        R_Q_D_globals[i] = F.cosine_similarity(img_global_features, text_global_features[i].unsqueeze(0).repeat(d_batch, 1), dim=1) # (d_batch, d_common), (d_batch, d_common) -> (d_batch,)

    P_D_Qs = F.softmax(R_Q_Ds * gamma_3, dim=0) # (d_batch, d_batch)
    P_Q_Ds = F.softmax(R_Q_Ds * gamma_3, dim=1) # (d_batch, d_batch)
    L_w_1 = -P_D_Qs.diag().log().sum()
    L_w_2 = -P_Q_Ds.diag().log().sum()

    P_D_Q_globals = F.softmax(R_Q_D_globals * gamma_3, dim=0) # (d_batch, d_batch)
    P_Q_D_globals = F.softmax(R_Q_D_globals * gamma_3, dim=1) # (d_batch, d_batch)
    L_s_1 = -P_D_Q_globals.diag().log().sum()
    L_s_2 = -P_Q_D_globals.diag().log().sum()

    loss = L_w_1 + L_w_2 + L_s_1 + L_s_2
    if visualize:
        return loss, R_Q_Ds, R_Q_D_globals, P_D_Qs, P_Q_Ds, P_D_Q_globals, P_Q_D_globals
    return loss

def loss_helper(img_local_features, text_local_features, gamma_1, gamma_2):
    ss = torch.bmm(text_local_features, img_local_features.transpose(1, 2)) # (d_batch, d_max_seq_len, d_common), (d_batch, d_img_regions, d_common) -> (d_batch, d_max_seq_len, d_img_regions)
    s_bars = F.softmax(ss, dim=1) # (d_batch, d_max_seq_len, d_img_regions) -> (d_batch, d_max_seq_len, d_img_regions)
    alphas = F.softmax(s_bars * gamma_1, dim=2) # (d_batch, d_max_seq_len, d_img_regions) -> (d_batch, d_max_seq_len, d_img_regions)
    cs = torch.bmm(alphas, img_local_features) # (d_batch, d_max_seq_len, d_img_regions), (d_batch, d_img_regions, d_common) -> (d_batch, d_max_seq_len, d_common)
    r_c_es = F.cosine_similarity(cs, text_local_features, dim=2) # (d_batch, d_max_seq_len, d_common), (d_batch, d_max_seq_len, d_common) -> (d_batch, d_max_seq_len)
    r_q_ds = (r_c_es * gamma_2).exp().sum(dim=1).log() # (d_batch, d_max_seq_len) -> (d_batch,) # TODO: raise to power 1/gamma_2 ?
    return r_q_ds

def test_damsm_loss():
    d_batch = 16
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

    d_img_regions = 17*17
    d_img_local_feature = 768
    d_img_global_feature = 2048
    d_max_seq_len = 23
    d_text_local_feature = 128
    d_text_global_feature = 128
    d_common = d_text_local_feature

    img_local_features = torch.randn(d_batch, d_img_regions, d_img_local_feature).to(device)
    img_global_features = torch.randn(d_batch, d_img_global_feature).to(device)
    text_local_features = torch.randn(d_batch, d_max_seq_len, d_text_local_feature).to(device)
    text_global_features = torch.randn(d_batch, d_text_global_feature).to(device)

    m1 = nn.Linear(d_img_local_feature, d_common).to(device).train()
    m2 = nn.Linear(d_img_global_feature, d_common).to(device).train()

    img_local_features = m1(img_local_features)
    img_global_features = m2(img_global_features)

    loss = damsm_loss(img_local_features, img_global_features, text_local_features, text_global_features)
    assert math.isfinite(loss)
    loss.backward()
    print('loss:', loss.item())

class DAMSMImageEncoder(nn.Module):
    def __init__(self, d_common=256, **kwargs):
        super().__init__()
        self.d_img_regions = 17*17
        self.d_common = d_common

        model = inception_v3(pretrained=True)
        # url = 'https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth'
        # model.load_state_dict(model_zoo.load_url(url))
        for param in model.parameters():
            param.requires_grad = False
        # print('Load pretrained model from ', url)
        # print(model)

        self.define_module(model)
        self.init_trainable_weights()

    def define_module(self, model):
        self.Conv2d_1a_3x3 = model.Conv2d_1a_3x3
        self.Conv2d_2a_3x3 = model.Conv2d_2a_3x3
        self.Conv2d_2b_3x3 = model.Conv2d_2b_3x3
        self.Conv2d_3b_1x1 = model.Conv2d_3b_1x1
        self.Conv2d_4a_3x3 = model.Conv2d_4a_3x3
        self.Mixed_5b = model.Mixed_5b
        self.Mixed_5c = model.Mixed_5c
        self.Mixed_5d = model.Mixed_5d
        self.Mixed_6a = model.Mixed_6a
        self.Mixed_6b = model.Mixed_6b
        self.Mixed_6c = model.Mixed_6c
        self.Mixed_6d = model.Mixed_6d
        self.Mixed_6e = model.Mixed_6e
        self.Mixed_7a = model.Mixed_7a
        self.Mixed_7b = model.Mixed_7b
        self.Mixed_7c = model.Mixed_7c

        self.conv_local_features = nn.Conv2d(768, self.d_common, kernel_size=1, stride=1, padding=0, bias=False)
        self.fc_global_features = nn.Linear(2048, self.d_common)

    def init_trainable_weights(self):
        initrange = 0.1
        self.conv_local_features.weight.data.uniform_(-initrange, initrange)
        self.fc_global_features.weight.data.uniform_(-initrange, initrange)

    def forward(self, x):
        features = None
        # --> fixed-size input: batch x 3 x 299 x 299
        x = nn.Upsample(size=(299, 299), mode='bilinear', align_corners=False)(x)
        # 299 x 299 x 3
        x = self.Conv2d_1a_3x3(x)
        # 149 x 149 x 32
        x = self.Conv2d_2a_3x3(x)
        # 147 x 147 x 32
        x = self.Conv2d_2b_3x3(x)
        # 147 x 147 x 64
        x = F.max_pool2d(x, kernel_size=3, stride=2)
        # 73 x 73 x 64
        x = self.Conv2d_3b_1x1(x)
        # 73 x 73 x 80
        x = self.Conv2d_4a_3x3(x)
        # 71 x 71 x 192

        x = F.max_pool2d(x, kernel_size=3, stride=2)
        # 35 x 35 x 192
        x = self.Mixed_5b(x)
        # 35 x 35 x 256
        x = self.Mixed_5c(x)
        # 35 x 35 x 288
        x = self.Mixed_5d(x)
        # 35 x 35 x 288

        x = self.Mixed_6a(x)
        # 17 x 17 x 768
        x = self.Mixed_6b(x)
        # 17 x 17 x 768
        x = self.Mixed_6c(x)
        # 17 x 17 x 768
        x = self.Mixed_6d(x)
        # 17 x 17 x 768
        x = self.Mixed_6e(x)
        # 17 x 17 x 768

        # image region features
        img_local_features = x
        # 17 x 17 x 768

        x = self.Mixed_7a(x)
        # 8 x 8 x 1280
        x = self.Mixed_7b(x)
        # 8 x 8 x 2048
        x = self.Mixed_7c(x)
        # 8 x 8 x 2048
        x = F.avg_pool2d(x, kernel_size=8)
        # 1 x 1 x 2048
        # x = F.dropout(x, training=self.training)
        # 1 x 1 x 2048
        x = x.view(x.size(0), -1)
        # 2048

        # global image features
        img_global_features = self.fc_global_features(x)
        # 512
        img_local_features = self.conv_local_features(img_local_features)
        img_local_features = img_local_features.view(-1, self.d_common, self.d_img_regions).transpose(1, 2).contiguous()
        return img_local_features, img_global_features

def test_damsm_image_encoder():
    d_batch = 4
    d_image_size = 64
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    img_enc = DAMSMImageEncoder().to(device).train()
    imgs = torch.randn(d_batch, 3, d_image_size, d_image_size).to(device)

    img_local_features, img_global_features = img_enc(imgs)

    assert img_local_features.size() == (d_batch, img_enc.d_img_regions, img_enc.d_common)
    assert img_global_features.size() == (d_batch, img_enc.d_common)

"""# DAMSM text encoder"""

class DAMSMTextEncoder(nn.Module):
    def __init__(self, d_vocab=1750, d_max_seq_len=23, d_text_embed=300, d_text_local_feature=256, drop_prob=0.5, **kwargs):
        super().__init__()

        assert d_text_local_feature % 2 == 0

        self.d_vocab = d_vocab
        self.drop_prob = drop_prob
        self.d_text_embed = d_text_embed
        self.d_max_seq_len = d_max_seq_len
        self.d_text_local_feature = d_text_local_feature
        self.d_text_global_feature = d_text_local_feature
        self.d_common = d_text_local_feature

        self.define_module()
        self.init_weights()

    def define_module(self):
        self.embed = nn.Embedding(self.d_vocab, self.d_text_embed)
        self.drop = nn.Dropout(self.drop_prob)
        self.rnn = nn.LSTM(self.d_text_embed, self.d_text_local_feature//2, batch_first=True, bidirectional=True)

    def init_weights(self):
        initrange = 0.1
        self.embed.weight.data.uniform_(-initrange, initrange)

    def forward(self, texts):
        text_embeds = self.drop(self.embed(texts))
        text_local_features, (text_global_features, _) = self.rnn(text_embeds)
        text_global_features = text_global_features.transpose(0, 1).reshape(-1, self.d_text_local_feature)
        return text_local_features, text_global_features

def test_damsm_text_encoder():
    d_batch = 4
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    text_enc = DAMSMTextEncoder().to(device).train()
    texts = torch.randint(low=0, high=text_enc.d_vocab, size=(d_batch, text_enc.d_max_seq_len)).to(device)

    text_local_features, text_global_features = text_enc(texts)

    assert text_local_features.size() == (d_batch, text_enc.d_max_seq_len, text_enc.d_common)
    assert text_global_features.size() == (d_batch, text_enc.d_common)

def test_encoders_and_loss():
    d_batch = 4
    d_image_size = 64

    img_enc = DAMSMImageEncoder().cuda().train()
    text_enc = DAMSMTextEncoder().cuda().train()

    assert img_enc.d_common == text_enc.d_common

    imgs = torch.randn(d_batch, 3, d_image_size, d_image_size).cuda()
    texts = torch.randint(low=0, high=text_enc.d_vocab, size=(d_batch, text_enc.d_max_seq_len)).cuda()

    img_local_features, img_global_features = img_enc(imgs)
    text_local_features, text_global_features = text_enc(texts)

    assert img_local_features.size() == (d_batch, img_enc.d_img_regions, img_enc.d_common)
    assert img_global_features.size() == (d_batch, img_enc.d_common)
    assert text_local_features.size() == (d_batch, text_enc.d_max_seq_len, text_enc.d_common)
    assert text_global_features.size() == (d_batch, text_enc.d_common)

    loss = damsm_loss(img_local_features, img_global_features, text_local_features, text_global_features)
    assert math.isfinite(loss)
    loss.backward()
    print('loss:', loss.item())

    with torch.no_grad():
        loss, R_Q_Ds, R_Q_D_globals, P_D_Qs, P_Q_Ds, P_D_Q_globals, P_Q_D_globals = damsm_loss(img_local_features, img_global_features, text_local_features, text_global_features, visualize=True)
        print('loss:', loss.item())
        for xs in [R_Q_Ds, R_Q_D_globals, P_D_Qs, P_Q_Ds, P_D_Q_globals, P_Q_D_globals]:
            assert xs.size() == (d_batch, d_batch)

# if __name__ == '__main__':
#     print('Running tests for CUB 200 2011 dataset:')
#     test_get_cub_200_2011()
# #     print('Running tests for OxfordFlowers102 dataset:')
# #     test_oxford_flowers_102()
#     print('Running tests for EMNLP2017 dataset:')
#     test_get_emnlp_2017()
#     print('Running tests for DAMSM loss and encoders:')
#     test_damsm_loss()
# #     test_damsm_image_encoder()
#     test_damsm_text_encoder()
# #     test_encoders_and_loss()
#     print('Done.')
# #

# %%
# def get_cub_200_2011(d_batch=4, should_pad=False, shuffle=True, **kwargs):
#     transform = transforms.Lambda(lambda x: (x.float() / 255.) * 2. - 1.)
#     train_set = CUB_200_2011(transform=transform, should_pad=should_pad, **kwargs)
#     if not should_pad:
#         def collate_fn(samples):
#             imgs, class_ids, caps = zip(*samples)
#             imgs = torch.stack(imgs)
#             class_ids = torch.tensor(class_ids, dtype=torch.long)
#             return imgs, class_ids, caps
#         train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True, collate_fn=collate_fn)
#     else:
#         train_loader = DataLoader(train_set, batch_size=d_batch, shuffle=shuffle, drop_last=True, num_workers=4, pin_memory=True)
#     return train_set, train_loader

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz (12.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy>=2.2.0 in c:\users\asus\anaconda3\lib\site-packages (from en-core-web-sm==2.2.0) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (8.0.16)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.26.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (4.62.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.9.1)
# Requirement already satisfied: setuptools in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (59.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.7.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.2)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.21.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\anaconda3\lib\site-packages (from packaging>=20.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\asus\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy>=2.2.0->en-core-web-sm==2.2.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\asus\appdata\roaming\python\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python38\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.4.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\asus\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asus\anaconda3\lib\site-packages (from jinja2->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.1.1)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.0-py3-none-any.whl size=12019124 sha256=4a64a7b710a7867198e12670955191bfd296e895dc95a81ce965775208d68bdd
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\fc\31\e9\092e6f05b2817c9cb45804a3d1bf2b9bf6575742c01819337c
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Asus\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
train_set, train_loader = get_cub_200_2011(split='train_val', d_batch=64)
print(len(train_set), len(train_loader))
# Out:
# hhh
# C:\Users\Asus\kaggle\input\cub-200-2011\metadata.pth
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5744/2659669550.py in <module>
# ----> 1 train_set, train_loader = get_cub_200_2011(split='train_val', d_batch=64)
#       2 print(len(train_set), len(train_loader))
#
# ~\AppData\Local\Temp/ipykernel_5744/2083800739.py in get_cub_200_2011(d_batch, should_pad, shuffle, **kwargs)
#     375     transform = transforms.Lambda(lambda x: (x.float() / 255.) * 2. - 1.)
#     376     print('hhh')
# --> 377     train_set = CUB_200_2011(transform=transform, should_pad=should_pad, **kwargs)
#     378     if not should_pad:
#     379         def collate_fn(samples):
#
# ~\AppData\Local\Temp/ipykernel_5744/2083800739.py in __init__(self, split, d_image_size, transform, should_pad, pad_to_length, no_start_end, **kwargs)
#     133
#     134         nlp = English()
# --> 135         self.tokenizer = nlp.Defaults.create_tokenizer(nlp) # Create a Tokenizer with the default settings for English including punctuation rules and exceptions
#     136
#     137         # images
#
# AttributeError: type object 'EnglishDefaults' has no attribute 'create_tokenizer'

# %%
import torch
import matplotlib.pyplot as plt
from utils import get_cub_200_2011
from torchvision.utils import make_grid

# %%
train_set, train_loader = get_cub_200_2011(split='train_val', d_batch=64)
print(len(train_set), len(train_loader))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5744/2659669550.py in <module>
# ----> 1 train_set, train_loader = get_cub_200_2011(split='train_val', d_batch=64)
#       2 print(len(train_set), len(train_loader))
#
# ~\utils.py in get_cub_200_2011(d_batch, should_pad, shuffle, **kwargs)
#     358
#     359     def __len__(self):
# --> 360         return len(self.seqs)
#     361
#     362 def to_one_hot(labels, d_classes):
#
# ~\utils.py in __init__(self, split, d_image_size, transform, should_pad, pad_to_length, no_start_end, **kwargs)
#      97         assert d_image_size in (64, 128, 256)
#      98         if should_pad:
# ---> 99             assert pad_to_length >= 3 # <START> foo <END> need at least length 3.
#     100
#     101         self.split = split
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     592         pickle_load_args['encoding'] = 'utf-8'
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#     596             # The zipfile reader is going to advance the current file position.
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/cub-200-2011\\metadata.pth'
